# %% [markdown]
# This is a follow-up of my [[Train] COVID-19 Detection using YOLOv5](https://www.kaggle.com/ayuraj/train-covid-19-detection-using-yolov5) kernel that will:
#
# * Train YOLOv5 in a cross validation setting (It's just repeating the same thing 5 times in case of 5-fold training).
#
# * Shows **ensembling** of different YOLOv5 models to get ensembled results.

# %% [markdown]
# # ☀️ Imports and Setup
#
# According to the official [Train Custom Data](https://github.com/ultralytics/yolov5/wiki/Train-Custom-Data) guide, YOLOv5 requires a certain directory structure.
#
# ```
# /parent_folder
#     /dataset
#          /images
#          /labels
#     /yolov5
# ```
#
# * We thus will create a `/tmp` directory. <br>
# * Download YOLOv5 repository and pip install the required dependencies. <br>
# * Install the latest version of W&B and login with your wandb account. You can create your free W&B account [here](https://wandb.ai/site).

# %%
# %cd ../
# !mkdir tmp
# %cd tmp
# Out:
# /kaggle
# /kaggle/tmp

# %%
# Download YOLOv5
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# Install dependencies
# %pip install -qr requirements.txt  # install dependencies

# %cd ../
import torch
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 8142, done.
# remote: Counting objects: 100% (454/454), done.
# remote: Compressing objects: 100% (196/196), done.
# remote: Total 8142 (delta 308), reused 375 (delta 258), pack-reused 7688
# Receiving objects: 100% (8142/8142), 9.46 MiB | 16.64 MiB/s, done.
# Resolving deltas: 100% (5604/5604), done.
# /kaggle/tmp/yolov5
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# Note: you may need to restart the kernel to use updated packages.
# /kaggle/tmp
# Setup complete. Using torch 1.7.0 (Tesla P100-PCIE-16GB)

# %%
# Install W&B 
# !pip install -q --upgrade wandb
# Login 
import wandb
wandb.login()
# Out:
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:  ········································
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# Necessary/extra dependencies. 
import os
import gc
import cv2 
# import wandb
import shutil
import numpy as np
import pandas as pd
pd.set_option('mode.chained_assignment', None)
from tqdm import tqdm
from shutil import copyfile
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold

#customize iPython writefile so we can write variables
from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))

# %% [markdown]
# # 🦆 Hyperparameters

# %%
TRAIN_PATH = '../input/siim-covid19-resized-to-256px-png/train'
IMG_SIZE = 256
BATCH_SIZE = 32
EPOCHS = 100
USE_FOLD = False
SEED = 42
NUM_FOLD = 5

# %% [markdown]
# # 🔨 Prepare Dataset
#
#
# This is the most important section when it comes to training an object detector with YOLOv5. The directory structure, bounding box format, etc must be in the correct order. This section builds every piece needed to train a YOLOv5 model.
#
# I am using [xhlulu's](https://www.kaggle.com/xhlulu) resized dataset. The uploaded 256x256 Kaggle dataset is [here](https://www.kaggle.com/xhlulu/siim-covid19-resized-to-256px-jpg). Find other image resolutions [here](https://www.kaggle.com/c/siim-covid19-detection/discussion/239918).
#
# * Create train-validation split. <br>
# * Create required `/dataset` folder structure and more the images to that folder. <br>
# * Create `data.yaml` file needed to train the model. <br>
# * Create bounding box coordinates in the required YOLO format.

# %% [markdown]
# ### Merge Study and Image level CSV files

# %%
# IMAGE LEVEL

# Load image level csv file
df = pd.read_csv('../input/train_image_level.csv') #siim-covid19-detection
# Load study level csv file
label_df = pd.read_csv('../input/train_study_level.csv')

# Modify values in the id column
df['id'] = df.apply(lambda row: row.id.split('_')[0], axis=1)
# Add absolute path
df['path'] = df.apply(lambda row: TRAIN_PATH+row.id+'.jpg', axis=1)
# Get image level labels
def image_level(row):
    label = row.label.split(' ')[0]
    if label == 'opacity': return 1
    else: return 0

df['image_level'] = df.apply(lambda row: image_level(row), axis=1)

# %%
df
# Out:
#                 id                                              boxes  \
# 0     000a312787f2  [{'x': 789.28836, 'y': 582.43035, 'width': 102...
# 1     000c3a3f293f                                                NaN
# 2     0012ff7358bc  [{'x': 677.42216, 'y': 197.97662, 'width': 867...
# 3     001398f4ff4f  [{'x': 2729, 'y': 2181.33331, 'width': 948.000...
# 4     001bd15d1891  [{'x': 623.23328, 'y': 1050, 'width': 714, 'he...
# ...            ...                                                ...
# 6329  ffcc6edd9445                                                NaN
# 6330  ffd91a2c4ca0                                                NaN
# 6331  ffd9b6cf2961  [{'x': 2197.38566, 'y': 841.07361, 'width': 31...
# 6332  ffdc682f7680  [{'x': 2729.27083, 'y': 332.26044, 'width': 14...
# 6333  ffe942c8655f  [{'x': 208.86463, 'y': 91.53448, 'width': 450....
#
#                                                   label StudyInstanceUID  \
# 0     opacity 1 789.28836 582.43035 1815.94498 2499....     5776db0cec75
# 1                                        none 1 0 0 1 1     ff0879eb20ed
# 2     opacity 1 677.42216 197.97662 1545.21983 1197....     9d514ce429a7
# 3       opacity 1 2729 2181.33331 3677.00012 2785.33331     28dddc8559b2
# 4     opacity 1 623.23328 1050 1337.23328 2156 opaci...     dfd9fdd85a3e
# ...                                                 ...              ...
# 6329                                     none 1 0 0 1 1     7e6c68462e06
# 6330                                     none 1 0 0 1 1     8332bdaddb6e
# 6331  opacity 1 2197.38566 841.07361 2513.80265 1292...     7eed9af03814
# 6332  opacity 1 2729.27083 332.26044 4225.52099 2936...     a0cb0b96fb3d
# 6333  opacity 1 208.86463 91.53448 659.8321 719.5892...     7d82d53204b8
#
#                                                    path  image_level
# 0     ../input/siim-covid19-resized-to-256px-png/tra...            1
# 1     ../input/siim-covid19-resized-to-256px-png/tra...            0
# 2     ../input/siim-covid19-resized-to-256px-png/tra...            1
# 3     ../input/siim-covid19-resized-to-256px-png/tra...            1
# 4     ../input/siim-covid19-resized-to-256px-png/tra...            1
# ...                                                 ...          ...
# 6329  ../input/siim-covid19-resized-to-256px-png/tra...            0
# 6330  ../input/siim-covid19-resized-to-256px-png/tra...            0
# 6331  ../input/siim-covid19-resized-to-256px-png/tra...            1
# 6332  ../input/siim-covid19-resized-to-256px-png/tra...            1
# 6333  ../input/siim-covid19-resized-to-256px-png/tra...            1
#
# [6334 rows x 6 columns]

# %%
# STUDY LEVEL

# Modify values in the id column
label_df['id'] = label_df.apply(lambda row: row.id.split('_')[0], axis=1)
# Rename the column id with StudyInstanceUID
label_df.columns = ['StudyInstanceUID', 'Negative for Pneumonia', 'Typical Appearance', 'Indeterminate Appearance', 'Atypical Appearance']

# Label encode study-level labels
labels = label_df[['Negative for Pneumonia','Typical Appearance','Indeterminate Appearance','Atypical Appearance']].values
labels = np.argmax(labels, axis=1)
label_df['study_level'] = labels

# ORIGINAL DIMENSION

# Load meta.csv file
meta_df = pd.read_csv('../input/meta.csv') #siim-covid19-resized-to-256px-png
train_meta_df = meta_df.loc[meta_df.split == 'train']
train_meta_df = train_meta_df.drop('split', axis=1)
train_meta_df.columns = ['id', 'dim0', 'dim1']

# Merge image-level and study-level
df = df.merge(label_df, on='StudyInstanceUID',how="left")
# Merge with meta_df
df = df.merge(train_meta_df, on='id',how="left")

# Write as csv file
# df.to_csv('_image_study_total.csv', index=False)

df
# Out:
#                 id                                              boxes  \
# 0     000a312787f2  [{'x': 789.28836, 'y': 582.43035, 'width': 102...
# 1     000c3a3f293f                                                NaN
# 2     0012ff7358bc  [{'x': 677.42216, 'y': 197.97662, 'width': 867...
# 3     001398f4ff4f  [{'x': 2729, 'y': 2181.33331, 'width': 948.000...
# 4     001bd15d1891  [{'x': 623.23328, 'y': 1050, 'width': 714, 'he...
# ...            ...                                                ...
# 6329  ffcc6edd9445                                                NaN
# 6330  ffd91a2c4ca0                                                NaN
# 6331  ffd9b6cf2961  [{'x': 2197.38566, 'y': 841.07361, 'width': 31...
# 6332  ffdc682f7680  [{'x': 2729.27083, 'y': 332.26044, 'width': 14...
# 6333  ffe942c8655f  [{'x': 208.86463, 'y': 91.53448, 'width': 450....
#
#                                                   label StudyInstanceUID  \
# 0     opacity 1 789.28836 582.43035 1815.94498 2499....     5776db0cec75
# 1                                        none 1 0 0 1 1     ff0879eb20ed
# 2     opacity 1 677.42216 197.97662 1545.21983 1197....     9d514ce429a7
# 3       opacity 1 2729 2181.33331 3677.00012 2785.33331     28dddc8559b2
# 4     opacity 1 623.23328 1050 1337.23328 2156 opaci...     dfd9fdd85a3e
# ...                                                 ...              ...
# 6329                                     none 1 0 0 1 1     7e6c68462e06
# 6330                                     none 1 0 0 1 1     8332bdaddb6e
# 6331  opacity 1 2197.38566 841.07361 2513.80265 1292...     7eed9af03814
# 6332  opacity 1 2729.27083 332.26044 4225.52099 2936...     a0cb0b96fb3d
# 6333  opacity 1 208.86463 91.53448 659.8321 719.5892...     7d82d53204b8
#
#                                                    path  image_level  \
# 0     ../input/siim-covid19-resized-to-256px-png/tra...            1
# 1     ../input/siim-covid19-resized-to-256px-png/tra...            0
# 2     ../input/siim-covid19-resized-to-256px-png/tra...            1
# 3     ../input/siim-covid19-resized-to-256px-png/tra...            1
# 4     ../input/siim-covid19-resized-to-256px-png/tra...            1
# ...                                                 ...          ...
# 6329  ../input/siim-covid19-resized-to-256px-png/tra...            0
# 6330  ../input/siim-covid19-resized-to-256px-png/tra...            0
# 6331  ../input/siim-covid19-resized-to-256px-png/tra...            1
# 6332  ../input/siim-covid19-resized-to-256px-png/tra...            1
# 6333  ../input/siim-covid19-resized-to-256px-png/tra...            1
#
#       Negative for Pneumonia  Typical Appearance  Indeterminate Appearance  \
# 0                          0                   1                         0
# 1                          1                   0                         0
# 2                          0                   1                         0
# 3                          0                   0                         0
# 4                          0                   1                         0
# ...                      ...                 ...                       ...
# 6329                       1                   0                         0
# 6330                       1                   0                         0
# 6331                       0                   1                         0
# 6332                       0                   1                         0
# 6333                       0                   1                         0
#
#       Atypical Appearance  study_level  dim0  dim1
# 0                       0            1  3488  4256
# 1                       0            0  2320  2832
# 2                       0            1  2544  3056
# 3                       1            3  3520  4280
# 4                       0            1  2800  3408
# ...                   ...          ...   ...   ...
# 6329                    0            0  4240  3480
# 6330                    0            0  2800  3408
# 6331                    0            1  2388  3050
# 6332                    0            1  3488  4256
# 6333                    0            1  1140  1387
#
# [6334 rows x 13 columns]

# %%
if 'train_fold.csv' in os.listdir(os.getcwd()) and USE_FOLD:
    df = pd.read_csv('train_fold.csv')
else:
    df = pd.read_csv('_image_study_total.csv')
    df['path'] = df.apply(lambda row: f'../input/siim-covid19-resized-to-256px-png/train/{row.id}.png', axis=1)
    
    # Group by Study Ids and remove images that are "assumed" to be mislabeled
    for grp_df in df.groupby('StudyInstanceUID'):
        grp_id, grp_df = grp_df[0], grp_df[1]
        if len(grp_df) == 1:
            pass
        else:
            for i in range(len(grp_df)):
                row = grp_df.loc[grp_df.index.values[i]]
                if row.study_level > 0 and row.boxes is np.nan:
                    df = df.drop(grp_df.index.values[i])
                    
    print('total number of images: ', len(df))
    
    # Create train and validation split.
    df = df.drop('boxes', axis=1).reset_index()
    Fold = StratifiedKFold(n_splits=NUM_FOLD, shuffle=True, random_state=SEED)
    for n, (train_index, val_index) in enumerate(Fold.split(df, df['image_level'])):
        df.loc[val_index, 'fold'] = int(n)
    df['fold'] = df['fold'].astype(int)

    df.to_csv('train_fold.csv', index=False)

df.head()
# Out:
# total number of images:  6112
#    index            id                                              label  \
# 0      0  000a312787f2  opacity 1 789.28836 582.43035 1815.94498 2499....
# 1      1  000c3a3f293f                                     none 1 0 0 1 1
# 2      2  0012ff7358bc  opacity 1 677.42216 197.97662 1545.21983 1197....
# 3      3  001398f4ff4f    opacity 1 2729 2181.33331 3677.00012 2785.33331
# 4      4  001bd15d1891  opacity 1 623.23328 1050 1337.23328 2156 opaci...
#
#   StudyInstanceUID  image_level  Negative for Pneumonia  Typical Appearance  \
# 0     5776db0cec75            1                       0                   1
# 1     ff0879eb20ed            0                       1                   0
# 2     9d514ce429a7            1                       0                   1
# 3     28dddc8559b2            1                       0                   0
# 4     dfd9fdd85a3e            1                       0                   1
#
#    Indeterminate Appearance  Atypical Appearance  study_level  dim0  dim1  \
# 0                         0                    0            1  3488  4256
# 1                         0                    0            0  2320  2832
# 2                         0                    0            1  2544  3056
# 3                         0                    1            3  3520  4280
# 4                         0                    0            1  2800  3408
#
#                                                 path  fold
# 0  ../input/siim-covid19-resized-to-256px-png/tra...     4
# 1  ../input/siim-covid19-resized-to-256px-png/tra...     3
# 2  ../input/siim-covid19-resized-to-256px-png/tra...     3
# 3  ../input/siim-covid19-resized-to-256px-png/tra...     4
# 4  ../input/siim-covid19-resized-to-256px-png/tra...     4

# %% [markdown]
# ## 🍚 Prepare Required Folder Structure
#
# The required folder structure for the dataset directory is:
#
# ```
# /parent_folder
#     /dataset
#          /images
#              /train
#              /val
#          /labels
#              /train
#              /val
#     /yolov5
# ```
#
# Note that I have named the directory `covid`.

# %%
# !pwd
# Out:
# /kaggle/tmp

# %%
if USE_FOLD:
    pass
else:
    # Remove existing dirs
    for fold in range(NUM_FOLD):
        # Prepare train and valid df
        train_df = df.loc[df.fold != fold].reset_index(drop=True)
        valid_df = df.loc[df.fold == fold].reset_index(drop=True)
        
        try:
            shutil.rmtree(f'dataset_folds_{fold}/images')
            shutil.rmtree(f'dataset_folds_{fold}/labels')
        except:
            print('No dirs')

        # Make new dirs
        os.makedirs(f'dataset_folds_{fold}/images/train', exist_ok=True)
        os.makedirs(f'dataset_folds_{fold}/images/valid', exist_ok=True)
        os.makedirs(f'dataset_folds_{fold}/labels/train', exist_ok=True)
        os.makedirs(f'dataset_folds_{fold}/labels/valid', exist_ok=True)

        # Move the images to relevant split folder.
        for i in tqdm(range(len(train_df))):
            row = train_df.loc[i]
            copyfile(row.path, f'dataset_folds_{fold}/images/train/{row.id}.png')
            
        for i in tqdm(range(len(valid_df))):
            row = valid_df.loc[i]
            copyfile(row.path, f'dataset_folds_{fold}/images/valid/{row.id}.png')
# Out:
#   0%|          | 6/4889 [00:00<01:29, 54.72it/s]
# No dirs
# 100%|██████████| 4889/4889 [00:48<00:00, 101.79it/s]
# 100%|██████████| 1223/1223 [00:11<00:00, 105.83it/s]
#   2%|▏         | 83/4889 [00:00<00:05, 823.60it/s]
# No dirs
# 100%|██████████| 4889/4889 [00:05<00:00, 913.12it/s]
# 100%|██████████| 1223/1223 [00:01<00:00, 968.45it/s]
#   2%|▏         | 105/4890 [00:00<00:04, 1049.83it/s]
# No dirs
# 100%|██████████| 4890/4890 [00:04<00:00, 1017.22it/s]
# 100%|██████████| 1222/1222 [00:01<00:00, 890.06it/s]
#   2%|▏         | 119/4890 [00:00<00:04, 1188.00it/s]
# No dirs
# 100%|██████████| 4890/4890 [00:04<00:00, 1211.29it/s]
# 100%|██████████| 1222/1222 [00:00<00:00, 1305.33it/s]
#   3%|▎         | 140/4890 [00:00<00:03, 1392.67it/s]
# No dirs
# 100%|██████████| 4890/4890 [00:03<00:00, 1301.88it/s]
# 100%|██████████| 1222/1222 [00:00<00:00, 1302.57it/s]

# %%
# !ls
# Out:
# _image_study_total.csv	dataset_folds_1  dataset_folds_3  train_fold.csv
# dataset_folds_0		dataset_folds_2  dataset_folds_4  yolov5

# %% [markdown]
# ## 🍜 Create `.YAML` file
#
# The `data.yaml`, is the dataset configuration file that defines
#
# 1. an "optional" download command/URL for auto-downloading,
# 2. a path to a directory of training images (or path to a *.txt file with a list of training images),
# 3. a path to a directory of validation images (or path to a *.txt file with a list of validation images),
# 4. the number of classes,
# 5. a list of class names.
#
# > 📍 Important: In this competition, each image can either belong to `opacity` or `none` image-level labels. That's why I have  used the number of classes, `nc` to be 2. YOLOv5 automatically handles the images without any bounding box coordinates.
#
# > 📍 Note: The `data.yaml` is created in the `yolov5/data` directory as required.

# %%
# Create .yaml file 
import yaml

for fold in range(NUM_FOLD):
    data_yaml = dict(
        train = f'../dataset_folds_{fold}/images/train',
        val = f'../dataset_folds_{fold}/images/valid',
        nc = 2,
        names = ['none', 'opacity']
    )

    # Note that I am creating the file in the yolov5/data/ directory.
    with open(f'yolov5/data/data_fold_{fold}.yaml', 'w') as outfile:
        yaml.dump(data_yaml, outfile, default_flow_style=True)
    
# %cat yolov5/data/data_fold_0.yaml
# Out:
# {names: [none, opacity], nc: 2, train: ../dataset_folds_0/images/train, val: ../dataset_folds_0/images/valid}

# %% [markdown]
# ## 🍮 Prepare Bounding Box Coordinated for YOLOv5
#
# For every image with **bounding box(es)** a `.txt` file with the same name as the image will be created in the format shown below:
#
# * One row per object. <br>
# * Each row is class `x_center y_center width height format`. <br>
# * Box coordinates must be in normalized xywh format (from 0 - 1). We can normalize by the boxes in pixels by dividing `x_center` and `width` by image width, and `y_center` and `height` by image height. <br>
# * Class numbers are zero-indexed (start from 0). <br>
#
# > 📍 Note: We don't have to remove the images without bounding boxes from the training or validation sets.

# %%
# Get the raw bounding box by parsing the row value of the label column.
# Ref: https://www.kaggle.com/yujiariyasu/plot-3positive-classes
def get_bbox(row):
    bboxes = []
    bbox = []
    for i, l in enumerate(row.label.split(' ')):
        if (i % 6 == 0) | (i % 6 == 1):
            continue
        bbox.append(float(l))
        if i % 6 == 5:
            bboxes.append(bbox)
            bbox = []  
            
    return bboxes

# Scale the bounding boxes according to the size of the resized image. 
def scale_bbox(row, bboxes):
    # Get scaling factor
    scale_x = IMG_SIZE/row.dim1
    scale_y = IMG_SIZE/row.dim0
    
    scaled_bboxes = []
    for bbox in bboxes:
        x = int(np.round(bbox[0]*scale_x, 4))
        y = int(np.round(bbox[1]*scale_y, 4))
        x1 = int(np.round(bbox[2]*(scale_x), 4))
        y1= int(np.round(bbox[3]*scale_y, 4))

        scaled_bboxes.append([x, y, x1, y1]) # xmin, ymin, xmax, ymax
        
    return scaled_bboxes

# Convert the bounding boxes in YOLO format.
def get_yolo_format_bbox(img_w, img_h, bboxes):
    yolo_boxes = []
    for bbox in bboxes:
        w = bbox[2] - bbox[0] # xmax - xmin
        h = bbox[3] - bbox[1] # ymax - ymin
        xc = bbox[0] + int(np.round(w/2)) # xmin + width/2
        yc = bbox[1] + int(np.round(h/2)) # ymin + height/2
        
        yolo_boxes.append([xc/img_w, yc/img_h, w/img_w, h/img_h]) # x_center y_center width height
    
    return yolo_boxes

# %%
def write_bbox_files(tmp_df, fold_num, split):
    path = f'dataset_folds_{fold}/labels/{split}'
    for i in tqdm(range(len(tmp_df))):
        row = tmp_df.loc[i]
        # Get image id
        img_id = row.id
        # Get image-level label
        label = row.image_level

        file_name = f'{path}/{img_id}.txt'

        if label==1:
            # Get bboxes
            bboxes = get_bbox(row)
            # Scale bounding boxes
            scale_bboxes = scale_bbox(row, bboxes)
            # Format for YOLOv5
            yolo_bboxes = get_yolo_format_bbox(IMG_SIZE, IMG_SIZE, scale_bboxes)

            with open(file_name, 'w') as f:
                for bbox in yolo_bboxes:
                    bbox = [1]+bbox
                    bbox = [str(i) for i in bbox]
                    bbox = ' '.join(bbox)
                    f.write(bbox)
                    f.write('\n')

if USE_FOLD:
    pass
else:
    # Prepare the txt files for bounding box
    for fold in range(NUM_FOLD):
        # Prepare train and valid df
        train_df = df.loc[df.fold != fold].reset_index(drop=True)
        valid_df = df.loc[df.fold == fold].reset_index(drop=True)
        
        # prepare label for train
        write_bbox_files(train_df, fold, 'train')
        # prepare label for valid
        write_bbox_files(valid_df, fold, 'valid')
# Out:
# 100%|██████████| 4889/4889 [00:02<00:00, 2035.71it/s]
# 100%|██████████| 1223/1223 [00:00<00:00, 2194.29it/s]
# 100%|██████████| 4889/4889 [00:02<00:00, 2229.27it/s]
# 100%|██████████| 1223/1223 [00:00<00:00, 2104.84it/s]
# 100%|██████████| 4890/4890 [00:01<00:00, 2501.27it/s]
# 100%|██████████| 1222/1222 [00:00<00:00, 2536.09it/s]
# 100%|██████████| 4890/4890 [00:01<00:00, 2470.23it/s]
# 100%|██████████| 1222/1222 [00:00<00:00, 2560.84it/s]
# 100%|██████████| 4890/4890 [00:02<00:00, 2431.76it/s]
# 100%|██████████| 1222/1222 [00:00<00:00, 2536.04it/s]

# %% [markdown]
# # 🚅 5 Fold Training with W&B

# %%
# %cd yolov5
# Out:
# /kaggle/tmp/yolov5

# %% [markdown]
# ```
# --img {IMG_SIZE} \ # Input image size.
# --batch {BATCH_SIZE} \ # Batch size
# --epochs {EPOCHS} \ # Number of epochs
# --data data.yaml \ # Configuration file
# --weights yolov5s.pt \ # Model name
# --save_period 1\ # Save model after interval
# --project kaggle-siim-covid # W&B project name
# ```

# %%
for fold in range(NUM_FOLD):    
    print('FOLD NUMBER: ', fold)
    # !python train.py --img {IMG_SIZE} \
                     --batch {BATCH_SIZE} \
                     --epochs {1} \
                     --data data_fold_{fold}.yaml \
                     --weights yolov5s.pt \
                     --save_period 10\
                     --project yolov5-covid19-folds\
                     --name yolov5s-e-100-img-256-fold-{fold}
    print('###########################################################################################\n')
# Out:
# FOLD NUMBER:  0
# train: weights=yolov5s.pt, cfg=, data=data_fold_0.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=1, batch_size=32, img_size=[256], rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache_images=False, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=yolov5-covid19-folds, entity=None, name=yolov5s-e-100-img-256-fold-0, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=10, artifact_alias=latest, local_rank=-1
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# 2021-07-15 01:59:37.850889: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# wandb: Currently logged in as: ayush-thakur (use `wandb login --relogin` to force relogin)
# 2021-07-15 01:59:43.389161: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# wandb: Tracking run with wandb version 0.10.33
# wandb: Syncing run yolov5s-e-100-img-256-fold-0
# wandb: ⭐️ View project at https://wandb.ai/ayush-thakur/yolov5-covid19-folds
# wandb: 🚀 View run at https://wandb.ai/ayush-thakur/yolov5-covid19-folds/runs/23wszq8p
# wandb: Run data is saved locally in /kaggle/tmp/yolov5/wandb/run-20210715_015941-23wszq8p
# wandb: Run `wandb offline` to turn off syncing.
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v5.0/yolov5s.pt to yolov5s.pt...
#
# CondaEnvException: Unable to determine environment
#
# Please re-run this command with one of the following options:
#
# * Provide an environment name via --name or -n
# * Re-run this command inside an activated conda environment.
#
# 100%|██████████████████████████████████████| 14.1M/14.1M [00:00<00:00, 16.3MB/s]
#
# train: Scanning '../dataset_folds_0/labels/train' images and labels...3435 found
# val: Scanning '../dataset_folds_0/labels/valid' images and labels...859 found, 3
# Plotting labels...
#
# autoanchor: Analyzing anchors... anchors/target = 5.77, Best Possible Recall (BPR) = 1.0000
#        0/0     1.04G   0.09527   0.01833   0.01219    0.1258        56       256
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       1223       1576      0.157      0.359      0.111     0.0224
#              opacity       1223       1576      0.157      0.359      0.111     0.0224
# Optimizer stripped from yolov5-covid19-folds/yolov5s-e-100-img-256-fold-0/weights/last.pt, 14.3MB
# Optimizer stripped from yolov5-covid19-folds/yolov5s-e-100-img-256-fold-0/weights/best.pt, 14.3MB
#
# wandb: Waiting for W&B process to finish, PID 907
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: /kaggle/tmp/yolov5/wandb/run-20210715_015941-23wszq8p/logs/debug.log
# wandb: Find internal logs for this run at: /kaggle/tmp/yolov5/wandb/run-20210715_015941-23wszq8p/logs/debug-internal.log
# wandb: Run summary:
# wandb:                 train/box_loss 0.09527
# wandb:                 train/obj_loss 0.01833
# wandb:                 train/cls_loss 0.01219
# wandb:              metrics/precision 0.15691
# wandb:                 metrics/recall 0.3585
# wandb:                metrics/mAP_0.5 0.11117
# wandb:           metrics/mAP_0.5:0.95 0.02237
# wandb:                   val/box_loss 0.07157
# wandb:                   val/obj_loss 0.01094
# wandb:                   val/cls_loss 0.00213
# wandb:                          x/lr0 0.00152
# wandb:                          x/lr1 0.00152
# wandb:                          x/lr2 0.08632
# wandb:                       _runtime 115
# wandb:                     _timestamp 1626314496
# wandb:                          _step 1
# wandb: Run history:
# wandb:         train/box_loss ▁
# wandb:         train/obj_loss ▁
# wandb:         train/cls_loss ▁
# wandb:      metrics/precision ▁
# wandb:         metrics/recall ▁
# wandb:        metrics/mAP_0.5 ▁
# wandb:   metrics/mAP_0.5:0.95 ▁
# wandb:           val/box_loss ▁
# wandb:           val/obj_loss ▁
# wandb:           val/cls_loss ▁
# wandb:                  x/lr0 ▁
# wandb:                  x/lr1 ▁
# wandb:                  x/lr2 ▁
# wandb:               _runtime ▁█
# wandb:             _timestamp ▁█
# wandb:                  _step ▁█
# wandb:
# wandb: Synced 5 W&B file(s), 49 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb:
# wandb: Synced yolov5s-e-100-img-256-fold-0: https://wandb.ai/ayush-thakur/yolov5-covid19-folds/runs/23wszq8p
# ###########################################################################################
#
# FOLD NUMBER:  1
# train: weights=yolov5s.pt, cfg=, data=data_fold_1.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=1, batch_size=32, img_size=[256], rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache_images=False, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=yolov5-covid19-folds, entity=None, name=yolov5s-e-100-img-256-fold-1, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=10, artifact_alias=latest, local_rank=-1
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# 2021-07-15 02:01:48.970774: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# wandb: Currently logged in as: ayush-thakur (use `wandb login --relogin` to force relogin)
# 2021-07-15 02:01:52.391279: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
#
# CondaEnvException: Unable to determine environment
#
# Please re-run this command with one of the following options:
#
# * Provide an environment name via --name or -n
# * Re-run this command inside an activated conda environment.
#
# wandb: Tracking run with wandb version 0.10.33
# wandb: Syncing run yolov5s-e-100-img-256-fold-1
# wandb: ⭐️ View project at https://wandb.ai/ayush-thakur/yolov5-covid19-folds
# wandb: 🚀 View run at https://wandb.ai/ayush-thakur/yolov5-covid19-folds/runs/3ixibbsc
# wandb: Run data is saved locally in /kaggle/tmp/yolov5/wandb/run-20210715_020150-3ixibbsc
# wandb: Run `wandb offline` to turn off syncing.
#
# train: Scanning '../dataset_folds_1/labels/train' images and labels...3435 found
# val: Scanning '../dataset_folds_1/labels/valid' images and labels...859 found, 3
# Plotting labels...
#
# autoanchor: Analyzing anchors... anchors/target = 5.76, Best Possible Recall (BPR) = 0.9998
#        0/0     1.04G   0.09526   0.01858   0.01215     0.126        53       256
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       1223       1570      0.251      0.313      0.176     0.0392
#              opacity       1223       1570      0.251      0.313      0.176     0.0392
# Optimizer stripped from yolov5-covid19-folds/yolov5s-e-100-img-256-fold-1/weights/last.pt, 14.3MB
# Optimizer stripped from yolov5-covid19-folds/yolov5s-e-100-img-256-fold-1/weights/best.pt, 14.3MB
#
# wandb: Waiting for W&B process to finish, PID 1151
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: /kaggle/tmp/yolov5/wandb/run-20210715_020150-3ixibbsc/logs/debug.log
# wandb: Find internal logs for this run at: /kaggle/tmp/yolov5/wandb/run-20210715_020150-3ixibbsc/logs/debug-internal.log
# wandb: Run summary:
# wandb:                 train/box_loss 0.09526
# wandb:                 train/obj_loss 0.01858
# wandb:                 train/cls_loss 0.01215
# wandb:              metrics/precision 0.25146
# wandb:                 metrics/recall 0.31338
# wandb:                metrics/mAP_0.5 0.17595
# wandb:           metrics/mAP_0.5:0.95 0.0392
# wandb:                   val/box_loss 0.0715
# wandb:                   val/obj_loss 0.01094
# wandb:                   val/cls_loss 0.00213
# wandb:                          x/lr0 0.00152
# wandb:                          x/lr1 0.00152
# wandb:                          x/lr2 0.08632
# wandb:                       _runtime 108
# wandb:                     _timestamp 1626314618
# wandb:                          _step 1
# wandb: Run history:
# wandb:         train/box_loss ▁
# wandb:         train/obj_loss ▁
# wandb:         train/cls_loss ▁
# wandb:      metrics/precision ▁
# wandb:         metrics/recall ▁
# wandb:        metrics/mAP_0.5 ▁
# wandb:   metrics/mAP_0.5:0.95 ▁
# wandb:           val/box_loss ▁
# wandb:           val/obj_loss ▁
# wandb:           val/cls_loss ▁
# wandb:                  x/lr0 ▁
# wandb:                  x/lr1 ▁
# wandb:                  x/lr2 ▁
# wandb:               _runtime ▁█
# wandb:             _timestamp ▁█
# wandb:                  _step ▁█
# wandb:
# wandb: Synced 5 W&B file(s), 49 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb:
# wandb: Synced yolov5s-e-100-img-256-fold-1: https://wandb.ai/ayush-thakur/yolov5-covid19-folds/runs/3ixibbsc
# ###########################################################################################
#
# FOLD NUMBER:  2
# train: weights=yolov5s.pt, cfg=, data=data_fold_2.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=1, batch_size=32, img_size=[256], rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache_images=False, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=yolov5-covid19-folds, entity=None, name=yolov5s-e-100-img-256-fold-2, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=10, artifact_alias=latest, local_rank=-1
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# 2021-07-15 02:03:50.584246: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# wandb: Currently logged in as: ayush-thakur (use `wandb login --relogin` to force relogin)
# 2021-07-15 02:03:53.959364: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# wandb: Tracking run with wandb version 0.10.33
# wandb: Syncing run yolov5s-e-100-img-256-fold-2
# wandb: ⭐️ View project at https://wandb.ai/ayush-thakur/yolov5-covid19-folds
# wandb: 🚀 View run at https://wandb.ai/ayush-thakur/yolov5-covid19-folds/runs/2r1rlinu
# wandb: Run data is saved locally in /kaggle/tmp/yolov5/wandb/run-20210715_020352-2r1rlinu
# wandb: Run `wandb offline` to turn off syncing.
#
#
# CondaEnvException: Unable to determine environment
#
# Please re-run this command with one of the following options:
#
# * Provide an environment name via --name or -n
# * Re-run this command inside an activated conda environment.
#
# train: Scanning '../dataset_folds_2/labels/train' images and labels...3435 found
# val: Scanning '../dataset_folds_2/labels/valid' images and labels...859 found, 3
# Plotting labels...
#
# autoanchor: Analyzing anchors... anchors/target = 5.76, Best Possible Recall (BPR) = 0.9998
#        0/0     1.04G   0.09526   0.01853   0.01226    0.1261        60       256
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       1222       1563      0.173      0.297      0.103     0.0211
#              opacity       1222       1563      0.173      0.297      0.103     0.0211
# Optimizer stripped from yolov5-covid19-folds/yolov5s-e-100-img-256-fold-2/weights/last.pt, 14.3MB
# Optimizer stripped from yolov5-covid19-folds/yolov5s-e-100-img-256-fold-2/weights/best.pt, 14.3MB
#
# wandb: Waiting for W&B process to finish, PID 1393
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: /kaggle/tmp/yolov5/wandb/run-20210715_020352-2r1rlinu/logs/debug.log
# wandb: Find internal logs for this run at: /kaggle/tmp/yolov5/wandb/run-20210715_020352-2r1rlinu/logs/debug-internal.log
# wandb: Run summary:
# wandb:                 train/box_loss 0.09526
# wandb:                 train/obj_loss 0.01853
# wandb:                 train/cls_loss 0.01226
# wandb:              metrics/precision 0.17263
# wandb:                 metrics/recall 0.29687
# wandb:                metrics/mAP_0.5 0.10304
# wandb:           metrics/mAP_0.5:0.95 0.02114
# wandb:                   val/box_loss 0.07306
# wandb:                   val/obj_loss 0.01163
# wandb:                   val/cls_loss 0.00196
# wandb:                          x/lr0 0.00152
# wandb:                          x/lr1 0.00152
# wandb:                          x/lr2 0.08632
# wandb:                       _runtime 107
# wandb:                     _timestamp 1626314739
# wandb:                          _step 1
# wandb: Run history:
# wandb:         train/box_loss ▁
# wandb:         train/obj_loss ▁
# wandb:         train/cls_loss ▁
# wandb:      metrics/precision ▁
# wandb:         metrics/recall ▁
# wandb:        metrics/mAP_0.5 ▁
# wandb:   metrics/mAP_0.5:0.95 ▁
# wandb:           val/box_loss ▁
# wandb:           val/obj_loss ▁
# wandb:           val/cls_loss ▁
# wandb:                  x/lr0 ▁
# wandb:                  x/lr1 ▁
# wandb:                  x/lr2 ▁
# wandb:               _runtime ▁█
# wandb:             _timestamp ▁█
# wandb:                  _step ▁█
# wandb:
# wandb: Synced 5 W&B file(s), 49 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb:
# wandb: Synced yolov5s-e-100-img-256-fold-2: https://wandb.ai/ayush-thakur/yolov5-covid19-folds/runs/2r1rlinu
# ###########################################################################################
#
# FOLD NUMBER:  3
# train: weights=yolov5s.pt, cfg=, data=data_fold_3.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=1, batch_size=32, img_size=[256], rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache_images=False, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=yolov5-covid19-folds, entity=None, name=yolov5s-e-100-img-256-fold-3, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=10, artifact_alias=latest, local_rank=-1
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# 2021-07-15 02:05:51.533125: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# wandb: Currently logged in as: ayush-thakur (use `wandb login --relogin` to force relogin)
# 2021-07-15 02:05:54.905266: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# wandb: Tracking run with wandb version 0.10.33
# wandb: Syncing run yolov5s-e-100-img-256-fold-3
# wandb: ⭐️ View project at https://wandb.ai/ayush-thakur/yolov5-covid19-folds
# wandb: 🚀 View run at https://wandb.ai/ayush-thakur/yolov5-covid19-folds/runs/ofykk5q4
# wandb: Run data is saved locally in /kaggle/tmp/yolov5/wandb/run-20210715_020553-ofykk5q4
# wandb: Run `wandb offline` to turn off syncing.
#
#
# CondaEnvException: Unable to determine environment
#
# Please re-run this command with one of the following options:
#
# * Provide an environment name via --name or -n
# * Re-run this command inside an activated conda environment.
#
# train: Scanning '../dataset_folds_3/labels/train' images and labels...3435 found
# val: Scanning '../dataset_folds_3/labels/valid' images and labels...859 found, 3
# Plotting labels...
#
# autoanchor: Analyzing anchors... anchors/target = 5.77, Best Possible Recall (BPR) = 1.0000
#        0/0     1.04G    0.0946   0.01854   0.01217    0.1253        63       256
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       1222       1553      0.239      0.321      0.156     0.0354
#              opacity       1222       1553      0.239      0.321      0.156     0.0354
# Optimizer stripped from yolov5-covid19-folds/yolov5s-e-100-img-256-fold-3/weights/last.pt, 14.3MB
# Optimizer stripped from yolov5-covid19-folds/yolov5s-e-100-img-256-fold-3/weights/best.pt, 14.3MB
#
# wandb: Waiting for W&B process to finish, PID 1623
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: /kaggle/tmp/yolov5/wandb/run-20210715_020553-ofykk5q4/logs/debug.log
# wandb: Find internal logs for this run at: /kaggle/tmp/yolov5/wandb/run-20210715_020553-ofykk5q4/logs/debug-internal.log
# wandb: Run summary:
# wandb:                 train/box_loss 0.0946
# wandb:                 train/obj_loss 0.01854
# wandb:                 train/cls_loss 0.01217
# wandb:              metrics/precision 0.23881
# wandb:                 metrics/recall 0.32067
# wandb:                metrics/mAP_0.5 0.15592
# wandb:           metrics/mAP_0.5:0.95 0.03542
# wandb:                   val/box_loss 0.07251
# wandb:                   val/obj_loss 0.01064
# wandb:                   val/cls_loss 0.00207
# wandb:                          x/lr0 0.00152
# wandb:                          x/lr1 0.00152
# wandb:                          x/lr2 0.08632
# wandb:                       _runtime 107
# wandb:                     _timestamp 1626314860
# wandb:                          _step 1
# wandb: Run history:
# wandb:         train/box_loss ▁
# wandb:         train/obj_loss ▁
# wandb:         train/cls_loss ▁
# wandb:      metrics/precision ▁
# wandb:         metrics/recall ▁
# wandb:        metrics/mAP_0.5 ▁
# wandb:   metrics/mAP_0.5:0.95 ▁
# wandb:           val/box_loss ▁
# wandb:           val/obj_loss ▁
# wandb:           val/cls_loss ▁
# wandb:                  x/lr0 ▁
# wandb:                  x/lr1 ▁
# wandb:                  x/lr2 ▁
# wandb:               _runtime ▁█
# wandb:             _timestamp ▁█
# wandb:                  _step ▁█
# wandb:
# wandb: Synced 5 W&B file(s), 49 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb:
# wandb: Synced yolov5s-e-100-img-256-fold-3: https://wandb.ai/ayush-thakur/yolov5-covid19-folds/runs/ofykk5q4
# ###########################################################################################
#
# FOLD NUMBER:  4
# train: weights=yolov5s.pt, cfg=, data=data_fold_4.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=1, batch_size=32, img_size=[256], rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache_images=False, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=yolov5-covid19-folds, entity=None, name=yolov5s-e-100-img-256-fold-4, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=10, artifact_alias=latest, local_rank=-1
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# 2021-07-15 02:07:52.315652: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# wandb: Currently logged in as: ayush-thakur (use `wandb login --relogin` to force relogin)
# 2021-07-15 02:07:55.746260: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# wandb: Tracking run with wandb version 0.10.33
# wandb: Syncing run yolov5s-e-100-img-256-fold-4
# wandb: ⭐️ View project at https://wandb.ai/ayush-thakur/yolov5-covid19-folds
# wandb: 🚀 View run at https://wandb.ai/ayush-thakur/yolov5-covid19-folds/runs/72j6wu9k
# wandb: Run data is saved locally in /kaggle/tmp/yolov5/wandb/run-20210715_020753-72j6wu9k
# wandb: Run `wandb offline` to turn off syncing.
#
#
# CondaEnvException: Unable to determine environment
#
# Please re-run this command with one of the following options:
#
# * Provide an environment name via --name or -n
# * Re-run this command inside an activated conda environment.
#
# train: Scanning '../dataset_folds_4/labels/train' images and labels...3436 found
# val: Scanning '../dataset_folds_4/labels/valid' images and labels...858 found, 3
# Plotting labels...
#
# autoanchor: Analyzing anchors... anchors/target = 5.77, Best Possible Recall (BPR) = 1.0000
#        0/0     1.04G   0.09471   0.01843   0.01213    0.1253        67       256
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       1222       1591      0.181      0.257     0.0977     0.0202
#              opacity       1222       1591      0.181      0.257     0.0977     0.0202
# Optimizer stripped from yolov5-covid19-folds/yolov5s-e-100-img-256-fold-4/weights/last.pt, 14.3MB
# Optimizer stripped from yolov5-covid19-folds/yolov5s-e-100-img-256-fold-4/weights/best.pt, 14.3MB
#
# wandb: Waiting for W&B process to finish, PID 1856
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: /kaggle/tmp/yolov5/wandb/run-20210715_020753-72j6wu9k/logs/debug.log
# wandb: Find internal logs for this run at: /kaggle/tmp/yolov5/wandb/run-20210715_020753-72j6wu9k/logs/debug-internal.log
# wandb: Run summary:
# wandb:                 train/box_loss 0.09471
# wandb:                 train/obj_loss 0.01843
# wandb:                 train/cls_loss 0.01213
# wandb:              metrics/precision 0.18119
# wandb:                 metrics/recall 0.25707
# wandb:                metrics/mAP_0.5 0.09769
# wandb:           metrics/mAP_0.5:0.95 0.02022
# wandb:                   val/box_loss 0.07403
# wandb:                   val/obj_loss 0.01169
# wandb:                   val/cls_loss 0.00209
# wandb:                          x/lr0 0.00152
# wandb:                          x/lr1 0.00152
# wandb:                          x/lr2 0.08632
# wandb:                       _runtime 108
# wandb:                     _timestamp 1626314982
# wandb:                          _step 1
# wandb: Run history:
# wandb:         train/box_loss ▁
# wandb:         train/obj_loss ▁
# wandb:         train/cls_loss ▁
# wandb:      metrics/precision ▁
# wandb:         metrics/recall ▁
# wandb:        metrics/mAP_0.5 ▁
# wandb:   metrics/mAP_0.5:0.95 ▁
# wandb:           val/box_loss ▁
# wandb:           val/obj_loss ▁
# wandb:           val/cls_loss ▁
# wandb:                  x/lr0 ▁
# wandb:                  x/lr1 ▁
# wandb:                  x/lr2 ▁
# wandb:               _runtime ▁█
# wandb:             _timestamp ▁█
# wandb:                  _step ▁█
# wandb:
# wandb: Synced 5 W&B file(s), 49 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb:
# wandb: Synced yolov5s-e-100-img-256-fold-4: https://wandb.ai/ayush-thakur/yolov5-covid19-folds/runs/72j6wu9k
# ###########################################################################################

# %% [markdown]
# I have trained YOLOv5 small using image resolution of 512x512 and 5 fold stratified split of the dataset. The models were trained using single V100 GPU. The GIF below shows the training metrics logged on the W&B dashboard.
#
# The model weights can be found [here](https://www.kaggle.com/ayuraj/yolo-models).
#
# ### [Check out the W&B Dashboard](https://wandb.ai/ayush-thakur/kaggle-covid19-folds)
#
# ![img](https://i.imgur.com/MlNRJgU.gif)

# %% [markdown]
# # ✈️ Get OOF Predictions

# %%
# !ls yolov5-covid19-folds
# Out:
# yolov5s-e-100-img-256-fold-0  yolov5s-e-100-img-256-fold-3
# yolov5s-e-100-img-256-fold-1  yolov5s-e-100-img-256-fold-4
# yolov5s-e-100-img-256-fold-2

# %%
MODEL_WEIGHTS = [
    'yolov5-covid19-folds/yolov5s-e-100-img-256-fold-0/weights/best.pt',
    'yolov5-covid19-folds/yolov5s-e-100-img-256-fold-1/weights/best.pt',
    'yolov5-covid19-folds/yolov5s-e-100-img-256-fold-2/weights/best.pt',
    'yolov5-covid19-folds/yolov5s-e-100-img-256-fold-3/weights/best.pt',
    'yolov5-covid19-folds/yolov5s-e-100-img-256-fold-4/weights/best.pt',
]

SOURCES = [
    '../dataset_folds_0/images/valid',
    '../dataset_folds_1/images/valid',
    '../dataset_folds_2/images/valid',
    '../dataset_folds_3/images/valid',
    '../dataset_folds_4/images/valid',
]

CONFIDENCE = [
    0.269, 0.268, 0.209, 0.179, 0.308
]

# %%
for fold in range(NUM_FOLD):
    print('FOLD NUMBER: ', fold)
    
    # !python detect.py --weights {MODEL_WEIGHTS[fold]} \
                      --source {SOURCES[fold]} \
                      --img {IMG_SIZE} \
                      --conf {CONFIDENCE[fold]} \
                      --iou-thres 0.5 \
                      --max-det 3 \
                      --name infer_fold_{fold}\
                      --save-txt \
                      --save-conf\
                      --nosave
    
    print('###########################################################################################\n')
# Out:
# detect: weights=['yolov5-covid19-folds/yolov5s-e-100-img-256-fold-0/weights/best.pt', 'yolov5-covid19-folds/yolov5s-e-100-img-256-fold-1/weights/best.pt', 'yolov5-covid19-folds/yolov5s-e-100-img-256-fold-2/weights/best.pt', 'yolov5-covid19-folds/yolov5s-e-100-img-256-fold-3/weights/best.pt', 'yolov5-covid19-folds/yolov5s-e-100-img-256-fold-4/weights/best.pt'], source=../dataset_folds_4/images/valid, imgsz=256, conf_thres=0.308, iou_thres=0.5, max_det=3, device=, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=True, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=infer_fold_4, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# Ensemble created with ['yolov5-covid19-folds/yolov5s-e-100-img-256-fold-0/weights/best.pt', 'yolov5-covid19-folds/yolov5s-e-100-img-256-fold-1/weights/best.pt', 'yolov5-covid19-folds/yolov5s-e-100-img-256-fold-2/weights/best.pt', 'yolov5-covid19-folds/yolov5s-e-100-img-256-fold-3/weights/best.pt', 'yolov5-covid19-folds/yolov5s-e-100-img-256-fold-4/weights/best.pt']
#
# image 1/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/000a312787f2.png: 256x256 1 opacity, Done. (0.095s)
# image 2/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/001398f4ff4f.png: 256x256 Done. (0.095s)
# image 3/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/001bd15d1891.png: 256x256 Done. (0.094s)
# image 4/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/0022227f5adf.png: 256x256 1 opacity, Done. (0.094s)
# image 5/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/006e2ac85d57.png: 256x256 1 opacity, Done. (0.095s)
# image 6/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/008ff73b4ef3.png: 256x256 Done. (0.093s)
# image 7/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/00a129830f4e.png: 256x256 Done. (0.095s)
# image 8/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/00e3a7e91a34.png: 256x256 Done. (0.094s)
# image 9/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/00fb65888ddf.png: 256x256 1 opacity, Done. (0.092s)
# image 10/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/010214f9b600.png: 256x256 1 opacity, Done. (0.092s)
# image 11/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/0133bf9a5f5c.png: 256x256 1 opacity, Done. (0.093s)
# image 12/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/01376c1ba556.png: 256x256 Done. (0.092s)
# image 13/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/0150df5b6f08.png: 256x256 Done. (0.093s)
# image 14/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/0171f8209991.png: 256x256 1 opacity, Done. (0.094s)
# image 15/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/018f32c6644f.png: 256x256 Done. (0.093s)
# image 16/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/01a869686037.png: 256x256 1 opacity, Done. (0.095s)
# image 17/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/01b3d67779e8.png: 256x256 Done. (0.095s)
# image 18/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/01bf68877dab.png: 256x256 1 opacity, Done. (0.095s)
# image 19/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/01f8945ece37.png: 256x256 1 opacity, Done. (0.094s)
# image 20/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/022085a0b648.png: 256x256 1 opacity, Done. (0.094s)
# image 21/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/02366ec75168.png: 256x256 Done. (0.094s)
# image 22/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/027473c590c1.png: 256x256 Done. (0.093s)
# image 23/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/0286138dab9b.png: 256x256 2 opacitys, Done. (0.095s)
# image 24/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/02eed7c620be.png: 256x256 1 opacity, Done. (0.094s)
# image 25/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/0326d6990386.png: 256x256 Done. (0.093s)
# image 26/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/035e8786afef.png: 256x256 1 opacity, Done. (0.094s)
# image 27/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/035f51150531.png: 256x256 1 opacity, Done. (0.145s)
# image 28/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/039159f7b61b.png: 256x256 1 opacity, Done. (0.135s)
# image 29/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/03a1614f51e7.png: 256x256 1 opacity, Done. (0.130s)
# image 30/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/041089ce263a.png: 256x256 2 opacitys, Done. (0.131s)
# image 31/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/041e01732a79.png: 256x256 1 opacity, Done. (0.099s)
# image 32/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/041ff8cc34cf.png: 256x256 Done. (0.092s)
# image 33/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/044839a5b51f.png: 256x256 Done. (0.093s)
# image 34/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/047d552a32a7.png: 256x256 Done. (0.095s)
# image 35/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/04a4a5b779fc.png: 256x256 Done. (0.095s)
# image 36/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/04e9977554a5.png: 256x256 1 opacity, Done. (0.096s)
# image 37/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/04ee02f3b685.png: 256x256 Done. (0.096s)
# image 38/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/055fc441c5e4.png: 256x256 Done. (0.095s)
# image 39/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/058d56025fa2.png: 256x256 Done. (0.094s)
# image 40/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/05bacfe4dcc2.png: 256x256 Done. (0.095s)
# image 41/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/05ccf13c1980.png: 256x256 1 opacity, Done. (0.095s)
# image 42/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/061797f81be0.png: 256x256 Done. (0.094s)
# image 43/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/06ee89a4efe9.png: 256x256 1 opacity, Done. (0.095s)
# image 44/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/06fa3a4d5dbd.png: 256x256 Done. (0.104s)
# image 45/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/0726c56e706d.png: 256x256 Done. (0.101s)
# image 46/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/072999833ab4.png: 256x256 2 opacitys, Done. (0.092s)
# image 47/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/075e8abf2787.png: 256x256 1 opacity, Done. (0.095s)
# image 48/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/078fb92e34d5.png: 256x256 1 opacity, Done. (0.092s)
# image 49/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/07cd26298a41.png: 256x256 1 opacity, Done. (0.092s)
# image 50/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/07d26e1998f3.png: 256x256 2 opacitys, Done. (0.092s)
# image 51/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/080f3ecd201b.png: 256x256 1 opacity, Done. (0.093s)
# image 52/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/0811fe666ab0.png: 256x256 Done. (0.091s)
# image 53/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/081c57bf820f.png: 256x256 2 opacitys, Done. (0.093s)
# image 54/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/083efcd38bc3.png: 256x256 Done. (0.092s)
# image 55/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/0846041c1efd.png: 256x256 Done. (0.096s)
# image 56/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/0846e5c4dfd2.png: 256x256 2 opacitys, Done. (0.103s)
# image 57/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/085170457a04.png: 256x256 2 opacitys, Done. (0.104s)
# image 58/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/08d165dbcbde.png: 256x256 1 opacity, Done. (0.105s)
# image 59/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/08fb5758220d.png: 256x256 Done. (0.103s)
# image 60/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/095ccce075d9.png: 256x256 Done. (0.102s)
# image 61/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/09e2e25583e7.png: 256x256 1 opacity, Done. (0.103s)
# image 62/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/0a0bb7af0cab.png: 256x256 2 opacitys, Done. (0.105s)
# image 63/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/0a31f51a2bca.png: 256x256 Done. (0.103s)
# image 64/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/0a3afeef9c01.png: 256x256 Done. (0.102s)
# image 65/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/0a4c00809b62.png: 256x256 1 opacity, Done. (0.104s)
# image 66/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/0a677ac5768f.png: 256x256 1 opacity, Done. (0.103s)
# image 67/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/0a9432bfcc5b.png: 256x256 1 opacity, Done. (0.103s)
# image 68/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/0abc1b4a90f5.png: 256x256 1 opacity, Done. (0.101s)
# image 69/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/0ac8924c4eee.png: 256x256 1 opacity, Done. (0.099s)
# image 70/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/0ad09f62fea8.png: 256x256 Done. (0.101s)
# image 71/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/0afaed6c0a69.png: 256x256 3 opacitys, Done. (0.099s)
# image 72/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/0b49d75e3b51.png: 256x256 Done. (0.097s)
# image 73/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/0b4a60630af2.png: 256x256 2 opacitys, Done. (0.099s)
# image 74/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/0b7ca4c86b9f.png: 256x256 Done. (0.097s)
# image 75/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/0b9add7616b0.png: 256x256 1 opacity, Done. (0.094s)
# image 76/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/0c7b15362352.png: 256x256 Done. (0.097s)
# image 77/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/0c7e3c0eda27.png: 256x256 2 opacitys, Done. (0.100s)
# image 78/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/0cf130895909.png: 256x256 1 opacity, Done. (0.097s)
# image 79/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/0d71137b53d7.png: 256x256 2 opacitys, Done. (0.099s)
# image 80/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/0d89b409d464.png: 256x256 2 opacitys, Done. (0.099s)
# image 81/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/0f545de555fd.png: 256x256 Done. (0.097s)
# image 82/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/0f6ef2363710.png: 256x256 2 opacitys, Done. (0.098s)
# image 83/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/0f75cc926071.png: 256x256 Done. (0.096s)
# image 84/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/102e27cde152.png: 256x256 2 opacitys, Done. (0.098s)
# image 85/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/10336427905f.png: 256x256 Done. (0.097s)
# image 86/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/10a3953d8325.png: 256x256 1 opacity, Done. (0.097s)
# image 87/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/1117adfb1445.png: 256x256 1 opacity, Done. (0.099s)
# image 88/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/11fba2355a5f.png: 256x256 1 opacity, Done. (0.097s)
# image 89/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/128304c0b63a.png: 256x256 Done. (0.095s)
# image 90/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/129a15123634.png: 256x256 Done. (0.096s)
# image 91/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/12b7ba1557a4.png: 256x256 Done. (0.096s)
# image 92/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/12b7dd8452de.png: 256x256 Done. (0.094s)
# image 93/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/12cafcd805f1.png: 256x256 Done. (0.095s)
# image 94/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/12fd7e210fae.png: 256x256 1 opacity, Done. (0.094s)
# image 95/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/12fed1674c84.png: 256x256 Done. (0.095s)
# image 96/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/132fc5897bff.png: 256x256 1 opacity, Done. (0.101s)
# image 97/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/1335b56b7a98.png: 256x256 Done. (0.096s)
# image 98/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/137dd4fedd7f.png: 256x256 2 opacitys, Done. (0.096s)
# image 99/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/13f2231e9d4b.png: 256x256 2 opacitys, Done. (0.095s)
# image 100/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/13ff01cf36f8.png: 256x256 1 opacity, Done. (0.095s)
# image 101/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/140deda13014.png: 256x256 Done. (0.094s)
# image 102/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/1419506711be.png: 256x256 Done. (0.095s)
# image 103/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/1444611cf962.png: 256x256 2 opacitys, Done. (0.100s)
# image 104/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/14b5b8104a38.png: 256x256 1 opacity, Done. (0.098s)
# image 105/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/15e6cb19e0df.png: 256x256 1 opacity, Done. (0.097s)
# image 106/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/15edbaf470f0.png: 256x256 1 opacity, Done. (0.097s)
# image 107/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/16219815d303.png: 256x256 Done. (0.098s)
# image 108/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/16dcc1ba1934.png: 256x256 Done. (0.100s)
# image 109/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/173c23887f9b.png: 256x256 1 opacity, Done. (0.099s)
# image 110/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/176bbcbb90e1.png: 256x256 1 opacity, Done. (0.098s)
# image 111/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/179b83581dcc.png: 256x256 Done. (0.095s)
# image 112/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/17a7f3706f0e.png: 256x256 Done. (0.094s)
# image 113/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/17de208479c3.png: 256x256 1 opacity, Done. (0.095s)
# image 114/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/17eb45bb77f5.png: 256x256 Done. (0.095s)
# image 115/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/180e25a4ff31.png: 256x256 2 opacitys, Done. (0.097s)
# image 116/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/18f38a3c9603.png: 256x256 Done. (0.098s)
# image 117/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/193e2bddd6fb.png: 256x256 2 opacitys, Done. (0.100s)
# image 118/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/1a1a7f2d1de9.png: 256x256 2 opacitys, Done. (0.100s)
# image 119/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/1adafe8816ac.png: 256x256 1 opacity, Done. (0.100s)
# image 120/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/1af51de0fc72.png: 256x256 2 opacitys, Done. (0.099s)
# image 121/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/1b369b36f933.png: 256x256 Done. (0.099s)
# image 122/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/1b97fb772253.png: 256x256 Done. (0.099s)
# image 123/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/1b98d395bdb5.png: 256x256 2 opacitys, Done. (0.101s)
# image 124/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/1c306780d2f7.png: 256x256 Done. (0.100s)
# image 125/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/1c7f9e0d648f.png: 256x256 Done. (0.102s)
# image 126/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/1c9bc3acd2db.png: 256x256 1 opacity, Done. (0.099s)
# image 127/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/1db7053ca14c.png: 256x256 1 opacity, Done. (0.097s)
# image 128/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/1dc3fa353adf.png: 256x256 1 opacity, Done. (0.097s)
# image 129/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/1dc7459cb081.png: 256x256 Done. (0.096s)
# image 130/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/1e136f0e5958.png: 256x256 1 opacity, Done. (0.097s)
# image 131/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/1e2ab5bceffb.png: 256x256 1 opacity, Done. (0.095s)
# image 132/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/1e5b41b660ef.png: 256x256 1 opacity, Done. (0.096s)
# image 133/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/1ea61cb23df6.png: 256x256 Done. (0.096s)
# image 134/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/1ebbe0481d58.png: 256x256 2 opacitys, Done. (0.101s)
# image 135/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/1f09d8254115.png: 256x256 2 opacitys, Done. (0.145s)
# image 136/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/1f40455598f5.png: 256x256 2 opacitys, Done. (0.137s)
# image 137/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/1fce5a22d0ac.png: 256x256 1 opacity, Done. (0.137s)
# image 138/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/202bc0f993a0.png: 256x256 Done. (0.134s)
# image 139/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/203b08d8bdc0.png: 256x256 1 opacity, Done. (0.097s)
# image 140/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/208129e06010.png: 256x256 2 opacitys, Done. (0.096s)
# image 141/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/211890ccc8d2.png: 256x256 1 opacity, Done. (0.098s)
# image 142/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/212b48b31b1d.png: 256x256 Done. (0.095s)
# image 143/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/216f1644fc2e.png: 256x256 Done. (0.107s)
# image 144/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/21f6548ae9d4.png: 256x256 Done. (0.096s)
# image 145/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/2204baf77803.png: 256x256 1 opacity, Done. (0.096s)
# image 146/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/220d7304a493.png: 256x256 1 opacity, Done. (0.094s)
# image 147/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/228083cd85ef.png: 256x256 Done. (0.095s)
# image 148/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/22b331ed8fe1.png: 256x256 Done. (0.097s)
# image 149/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/243d84bb9946.png: 256x256 Done. (0.096s)
# image 150/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/2446cdfa1f2d.png: 256x256 Done. (0.096s)
# image 151/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/246d60d4df0b.png: 256x256 1 opacity, Done. (0.098s)
# image 152/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/24edd931748d.png: 256x256 2 opacitys, Done. (0.097s)
# image 153/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/25451ff5a571.png: 256x256 3 opacitys, Done. (0.096s)
# image 154/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/25516b6f6f44.png: 256x256 1 opacity, Done. (0.097s)
# image 155/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/258fea606884.png: 256x256 1 opacity, Done. (0.095s)
# image 156/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/25a090ab5ac1.png: 256x256 1 opacity, Done. (0.094s)
# image 157/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/265c8659d53b.png: 256x256 Done. (0.094s)
# image 158/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/267f44ef1151.png: 256x256 Done. (0.093s)
# image 159/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/26a9c98c2e39.png: 256x256 2 opacitys, Done. (0.094s)
# image 160/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/26ce9d56bae8.png: 256x256 2 opacitys, Done. (0.098s)
# image 161/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/276f6e25e85f.png: 256x256 1 opacity, Done. (0.097s)
# image 162/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/27bd4ea4ed28.png: 256x256 3 opacitys, Done. (0.097s)
# image 163/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/27c93fadef8a.png: 256x256 2 opacitys, Done. (0.095s)
# image 164/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/27e463d224ef.png: 256x256 1 opacity, Done. (0.097s)
# image 165/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/281e109c7644.png: 256x256 1 opacity, Done. (0.096s)
# image 166/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/28322cd5b3a4.png: 256x256 Done. (0.097s)
# image 167/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/2839d43f4706.png: 256x256 Done. (0.100s)
# image 168/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/2857435b9c7c.png: 256x256 1 opacity, Done. (0.098s)
# image 169/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/2870e488fd4d.png: 256x256 1 opacity, Done. (0.098s)
# image 170/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/2881f8699879.png: 256x256 Done. (0.097s)
# image 171/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/28e9e044dc31.png: 256x256 1 opacity, Done. (0.097s)
# image 172/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/2905f86286db.png: 256x256 2 opacitys, Done. (0.098s)
# image 173/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/2967d69518ac.png: 256x256 1 opacity, Done. (0.101s)
# image 174/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/2984d39e3801.png: 256x256 Done. (0.097s)
# image 175/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/299ca999e917.png: 256x256 1 opacity, Done. (0.097s)
# image 176/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/29a62f1d3a51.png: 256x256 2 opacitys, Done. (0.095s)
# image 177/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/29b23a11d1e4.png: 256x256 1 opacity, Done. (0.096s)
# image 178/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/29f2f88bcabe.png: 256x256 Done. (0.096s)
# image 179/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/2a03d1c9b41f.png: 256x256 2 opacitys, Done. (0.097s)
# image 180/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/2a7181500a00.png: 256x256 1 opacity, Done. (0.097s)
# image 181/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/2afda837a767.png: 256x256 Done. (0.095s)
# image 182/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/2b37bc3747ad.png: 256x256 2 opacitys, Done. (0.097s)
# image 183/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/2b3e7de602cc.png: 256x256 1 opacity, Done. (0.095s)
# image 184/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/2b96751bae1a.png: 256x256 3 opacitys, Done. (0.095s)
# image 185/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/2bcb650baf45.png: 256x256 1 opacity, Done. (0.095s)
# image 186/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/2bff2d35a6cc.png: 256x256 1 opacity, Done. (0.095s)
# image 187/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/2c501267c8db.png: 256x256 1 opacity, Done. (0.095s)
# image 188/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/2cdc7c6d320c.png: 256x256 1 opacity, Done. (0.097s)
# image 189/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/2d20205cca4d.png: 256x256 Done. (0.093s)
# image 190/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/2d50da581cb3.png: 256x256 1 opacity, Done. (0.095s)
# image 191/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/2d5e59b1aeec.png: 256x256 1 opacity, Done. (0.094s)
# image 192/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/2d72d653c4ed.png: 256x256 2 opacitys, Done. (0.094s)
# image 193/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/2db0feefc063.png: 256x256 3 opacitys, Done. (0.096s)
# image 194/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/2db404b60c2d.png: 256x256 Done. (0.094s)
# image 195/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/2df3f5e80d5b.png: 256x256 Done. (0.094s)
# image 196/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/2e10eba82c2b.png: 256x256 1 opacity, Done. (0.097s)
# image 197/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/2ed1dfce5a95.png: 256x256 1 opacity, Done. (0.096s)
# image 198/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/2ef7ed8ae9c8.png: 256x256 Done. (0.098s)
# image 199/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/2f1ce67c8d80.png: 256x256 Done. (0.095s)
# image 200/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/2f425fbd336f.png: 256x256 2 opacitys, Done. (0.099s)
# image 201/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/2fa1e735585b.png: 256x256 2 opacitys, Done. (0.100s)
# image 202/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/2fde99e8eece.png: 256x256 Done. (0.097s)
# image 203/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/30159ae10968.png: 256x256 1 opacity, Done. (0.095s)
# image 204/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/301eaf1a1afe.png: 256x256 Done. (0.095s)
# image 205/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3020a0522e22.png: 256x256 1 opacity, Done. (0.098s)
# image 206/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/30ccf60a7c44.png: 256x256 1 opacity, Done. (0.098s)
# image 207/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/30eaa5d1c04f.png: 256x256 1 opacity, Done. (0.097s)
# image 208/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/30eae2ee5011.png: 256x256 1 opacity, Done. (0.097s)
# image 209/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/30ecd2d4dce8.png: 256x256 Done. (0.096s)
# image 210/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/30fa38c1426f.png: 256x256 1 opacity, Done. (0.097s)
# image 211/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/30ff8e344be3.png: 256x256 2 opacitys, Done. (0.097s)
# image 212/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/31376011baec.png: 256x256 1 opacity, Done. (0.097s)
# image 213/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/31699372f456.png: 256x256 1 opacity, Done. (0.096s)
# image 214/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/31d40712a358.png: 256x256 1 opacity, Done. (0.096s)
# image 215/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/31d499dd751d.png: 256x256 1 opacity, Done. (0.094s)
# image 216/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/31ed6ca7181f.png: 256x256 1 opacity, Done. (0.093s)
# image 217/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/32579cfb5545.png: 256x256 Done. (0.094s)
# image 218/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/32d66d7bbb5a.png: 256x256 2 opacitys, Done. (0.095s)
# image 219/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/32ebc75d961e.png: 256x256 Done. (0.092s)
# image 220/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/330f08b39d19.png: 256x256 1 opacity, Done. (0.092s)
# image 221/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/336d2b8392f9.png: 256x256 2 opacitys, Done. (0.092s)
# image 222/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/336db847af0e.png: 256x256 Done. (0.095s)
# image 223/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/33889ee019d8.png: 256x256 1 opacity, Done. (0.094s)
# image 224/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/338c9d452ba2.png: 256x256 Done. (0.093s)
# image 225/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/339898ec49b3.png: 256x256 1 opacity, Done. (0.094s)
# image 226/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/33c6bfa1895d.png: 256x256 3 opacitys, Done. (0.093s)
# image 227/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/341787fb81c7.png: 256x256 1 opacity, Done. (0.094s)
# image 228/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/343699137ae1.png: 256x256 Done. (0.093s)
# image 229/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/34422c5a6860.png: 256x256 Done. (0.094s)
# image 230/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/34a0ef23101b.png: 256x256 3 opacitys, Done. (0.096s)
# image 231/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/34d78e39990b.png: 256x256 Done. (0.094s)
# image 232/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/34f30a40ddc4.png: 256x256 Done. (0.095s)
# image 233/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3503e6325419.png: 256x256 Done. (0.099s)
# image 234/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/35f3e874a4d5.png: 256x256 2 opacitys, Done. (0.097s)
# image 235/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3615df9cfc90.png: 256x256 Done. (0.100s)
# image 236/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/36400b03d8b0.png: 256x256 2 opacitys, Done. (0.099s)
# image 237/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/364e2b97c131.png: 256x256 2 opacitys, Done. (0.099s)
# image 238/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3670de872788.png: 256x256 1 opacity, Done. (0.102s)
# image 239/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/36a35a318b14.png: 256x256 Done. (0.095s)
# image 240/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/36cf2080b192.png: 256x256 1 opacity, Done. (0.094s)
# image 241/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/36e787810ece.png: 256x256 Done. (0.095s)
# image 242/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/36fb08cd22db.png: 256x256 2 opacitys, Done. (0.096s)
# image 243/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/373499fd6494.png: 256x256 1 opacity, Done. (0.110s)
# image 244/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/374fe1b05022.png: 256x256 1 opacity, Done. (0.145s)
# image 245/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/380bc51923e1.png: 256x256 3 opacitys, Done. (0.142s)
# image 246/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3818ea7d26b2.png: 256x256 3 opacitys, Done. (0.135s)
# image 247/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/382f83c41da1.png: 256x256 2 opacitys, Done. (0.132s)
# image 248/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3855902bcfc6.png: 256x256 1 opacity, Done. (0.106s)
# image 249/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/387d752f1af4.png: 256x256 1 opacity, Done. (0.097s)
# image 250/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3892dd928d72.png: 256x256 1 opacity, Done. (0.096s)
# image 251/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/38ab5750fb0f.png: 256x256 2 opacitys, Done. (0.095s)
# image 252/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/38db8a56a857.png: 256x256 1 opacity, Done. (0.096s)
# image 253/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3981fd745610.png: 256x256 1 opacity, Done. (0.098s)
# image 254/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/39acf134b0a1.png: 256x256 2 opacitys, Done. (0.097s)
# image 255/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3a21e049fb15.png: 256x256 2 opacitys, Done. (0.094s)
# image 256/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3a85c5bfcd7b.png: 256x256 2 opacitys, Done. (0.094s)
# image 257/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3ad8424be8d9.png: 256x256 Done. (0.095s)
# image 258/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3afaceb34345.png: 256x256 3 opacitys, Done. (0.096s)
# image 259/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3b31c91dd63b.png: 256x256 1 opacity, Done. (0.096s)
# image 260/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3b61e209092b.png: 256x256 Done. (0.094s)
# image 261/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3b95973fa9d7.png: 256x256 Done. (0.094s)
# image 262/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3b982073ec16.png: 256x256 Done. (0.094s)
# image 263/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3bce64c0c959.png: 256x256 1 opacity, Done. (0.093s)
# image 264/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3be2137ceea5.png: 256x256 1 opacity, Done. (0.097s)
# image 265/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3bea5bdbe6dc.png: 256x256 Done. (0.094s)
# image 266/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3c2bdbeb0046.png: 256x256 Done. (0.096s)
# image 267/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3cfb0ca1d73d.png: 256x256 Done. (0.095s)
# image 268/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3d34f6d50ed6.png: 256x256 3 opacitys, Done. (0.094s)
# image 269/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3d963eeddaf7.png: 256x256 3 opacitys, Done. (0.095s)
# image 270/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3d9c95938f42.png: 256x256 1 opacity, Done. (0.098s)
# image 271/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3df2c9d30cdf.png: 256x256 1 opacity, Done. (0.095s)
# image 272/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3e119259f2f7.png: 256x256 2 opacitys, Done. (0.095s)
# image 273/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3e2da8980634.png: 256x256 3 opacitys, Done. (0.095s)
# image 274/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3e3a03d4b313.png: 256x256 2 opacitys, Done. (0.097s)
# image 275/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3e63eefbf3d6.png: 256x256 1 opacity, Done. (0.095s)
# image 276/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3e7b2ffc97db.png: 256x256 1 opacity, Done. (0.093s)
# image 277/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3ed100de7738.png: 256x256 Done. (0.093s)
# image 278/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3eda96805867.png: 256x256 Done. (0.092s)
# image 279/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3fbb832d4c87.png: 256x256 Done. (0.092s)
# image 280/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3fdc2614d5d9.png: 256x256 2 opacitys, Done. (0.093s)
# image 281/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/3ff62f6ba1c6.png: 256x256 1 opacity, Done. (0.094s)
# image 282/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4039de3f81c8.png: 256x256 2 opacitys, Done. (0.092s)
# image 283/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4044589e4d6f.png: 256x256 1 opacity, Done. (0.094s)
# image 284/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/40666b956095.png: 256x256 1 opacity, Done. (0.095s)
# image 285/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/40684c5ec4d8.png: 256x256 Done. (0.095s)
# image 286/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/407bc7059973.png: 256x256 Done. (0.095s)
# image 287/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/40844df2c2ce.png: 256x256 1 opacity, Done. (0.098s)
# image 288/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/409b4a178e25.png: 256x256 Done. (0.102s)
# image 289/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/40cf9721e428.png: 256x256 1 opacity, Done. (0.099s)
# image 290/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/40dc04f31034.png: 256x256 Done. (0.118s)
# image 291/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/416bc57ec67d.png: 256x256 Done. (0.140s)
# image 292/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/41b1d441dcde.png: 256x256 1 opacity, Done. (0.135s)
# image 293/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/41b6fe25b370.png: 256x256 1 opacity, Done. (0.134s)
# image 294/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/41e9a794b342.png: 256x256 2 opacitys, Done. (0.148s)
# image 295/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/422220ffba3a.png: 256x256 1 opacity, Done. (0.132s)
# image 296/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4227ca3f0d1d.png: 256x256 1 opacity, Done. (0.142s)
# image 297/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4254395bc50a.png: 256x256 1 opacity, Done. (0.144s)
# image 298/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/42a27e1fa3fa.png: 256x256 3 opacitys, Done. (0.111s)
# image 299/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/42ae168b660f.png: 256x256 2 opacitys, Done. (0.106s)
# image 300/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/42b46c2e9d1d.png: 256x256 2 opacitys, Done. (0.108s)
# image 301/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/42c88918c2b1.png: 256x256 1 opacity, Done. (0.106s)
# image 302/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/42f5eca1848b.png: 256x256 Done. (0.102s)
# image 303/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/42fa8da416c9.png: 256x256 1 opacity, Done. (0.103s)
# image 304/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/433640e6ea5e.png: 256x256 1 opacity, Done. (0.102s)
# image 305/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4368a4b5ad6d.png: 256x256 1 opacity, Done. (0.101s)
# image 306/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4390dc824c58.png: 256x256 Done. (0.099s)
# image 307/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/43d8cc4504b3.png: 256x256 2 opacitys, Done. (0.106s)
# image 308/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/44325f6654eb.png: 256x256 3 opacitys, Done. (0.101s)
# image 309/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/446701af723a.png: 256x256 2 opacitys, Done. (0.103s)
# image 310/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4484ae4d0f58.png: 256x256 1 opacity, Done. (0.102s)
# image 311/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4496cad92371.png: 256x256 3 opacitys, Done. (0.102s)
# image 312/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/44d9c1a0290e.png: 256x256 3 opacitys, Done. (0.101s)
# image 313/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/45396bf8a4d3.png: 256x256 1 opacity, Done. (0.101s)
# image 314/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/455a7af10292.png: 256x256 Done. (0.100s)
# image 315/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/458d3c84b5d4.png: 256x256 3 opacitys, Done. (0.099s)
# image 316/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/45a8ac8979e1.png: 256x256 Done. (0.099s)
# image 317/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/462a64ef01e3.png: 256x256 Done. (0.098s)
# image 318/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/463eb8a9426b.png: 256x256 2 opacitys, Done. (0.100s)
# image 319/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/46693c940f64.png: 256x256 1 opacity, Done. (0.099s)
# image 320/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/46e4bd625d3f.png: 256x256 Done. (0.099s)
# image 321/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/46ef96aea886.png: 256x256 1 opacity, Done. (0.099s)
# image 322/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/472b6afa3709.png: 256x256 Done. (0.099s)
# image 323/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/47660080f1bc.png: 256x256 1 opacity, Done. (0.098s)
# image 324/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/47716ab91efa.png: 256x256 Done. (0.098s)
# image 325/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/478d6e906137.png: 256x256 Done. (0.098s)
# image 326/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/47942a02592a.png: 256x256 1 opacity, Done. (0.099s)
# image 327/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/47d7f75aa5fc.png: 256x256 3 opacitys, Done. (0.100s)
# image 328/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/47e83ede80c1.png: 256x256 1 opacity, Done. (0.100s)
# image 329/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4818a62bb220.png: 256x256 Done. (0.099s)
# image 330/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/482b482773ba.png: 256x256 1 opacity, Done. (0.101s)
# image 331/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/48a2d8eba182.png: 256x256 2 opacitys, Done. (0.099s)
# image 332/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/48c0fea2d415.png: 256x256 1 opacity, Done. (0.101s)
# image 333/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/48d4589736ff.png: 256x256 Done. (0.105s)
# image 334/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4914ad588781.png: 256x256 Done. (0.100s)
# image 335/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/499c4b6c9783.png: 256x256 1 opacity, Done. (0.102s)
# image 336/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/49cc605a04ae.png: 256x256 Done. (0.099s)
# image 337/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4a5e11ad2ea0.png: 256x256 1 opacity, Done. (0.107s)
# image 338/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4af7aa9e0686.png: 256x256 1 opacity, Done. (0.099s)
# image 339/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4afdc30fbb41.png: 256x256 Done. (0.100s)
# image 340/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4b17794e0851.png: 256x256 Done. (0.100s)
# image 341/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4b2468cc4bfe.png: 256x256 Done. (0.097s)
# image 342/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4b78153f9d46.png: 256x256 1 opacity, Done. (0.095s)
# image 343/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4b79ad26c2bd.png: 256x256 1 opacity, Done. (0.096s)
# image 344/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4b8f99cecd6b.png: 256x256 1 opacity, Done. (0.096s)
# image 345/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4b9cee7ecf44.png: 256x256 1 opacity, Done. (0.095s)
# image 346/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4bb94cd7f2f4.png: 256x256 1 opacity, Done. (0.096s)
# image 347/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4bee3fb83d26.png: 256x256 1 opacity, Done. (0.143s)
# image 348/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4c41ee92ec4d.png: 256x256 3 opacitys, Done. (0.142s)
# image 349/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4c45ed919f45.png: 256x256 2 opacitys, Done. (0.135s)
# image 350/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4c951c9bf926.png: 256x256 Done. (0.132s)
# image 351/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4cc42e634f49.png: 256x256 Done. (0.105s)
# image 352/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4cf49226c69f.png: 256x256 Done. (0.096s)
# image 353/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4d15169fe52c.png: 256x256 1 opacity, Done. (0.101s)
# image 354/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4d17a4779c86.png: 256x256 2 opacitys, Done. (0.098s)
# image 355/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4d8739e124ae.png: 256x256 Done. (0.095s)
# image 356/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4d94d9d0f8df.png: 256x256 1 opacity, Done. (0.094s)
# image 357/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4deec2dd94da.png: 256x256 1 opacity, Done. (0.094s)
# image 358/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4df6cc0a6472.png: 256x256 Done. (0.092s)
# image 359/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4e4963451900.png: 256x256 1 opacity, Done. (0.093s)
# image 360/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4e647a32aae9.png: 256x256 1 opacity, Done. (0.094s)
# image 361/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4e8f69e4ffa4.png: 256x256 1 opacity, Done. (0.093s)
# image 362/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4e94dc5b7c52.png: 256x256 1 opacity, Done. (0.093s)
# image 363/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4e95d8ca7f2f.png: 256x256 2 opacitys, Done. (0.092s)
# image 364/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4ed22347ea95.png: 256x256 Done. (0.092s)
# image 365/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4ef5fa3a4bc6.png: 256x256 2 opacitys, Done. (0.095s)
# image 366/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4efd20c837dc.png: 256x256 1 opacity, Done. (0.096s)
# image 367/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4f08261dc040.png: 256x256 1 opacity, Done. (0.094s)
# image 368/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4f0abed3f35c.png: 256x256 Done. (0.095s)
# image 369/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4f0b6e8557db.png: 256x256 Done. (0.093s)
# image 370/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4f11b62bab24.png: 256x256 Done. (0.093s)
# image 371/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4f257ce09b76.png: 256x256 Done. (0.097s)
# image 372/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4f57c61c596a.png: 256x256 1 opacity, Done. (0.096s)
# image 373/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4f6b571c20f0.png: 256x256 2 opacitys, Done. (0.095s)
# image 374/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4f7d8597167f.png: 256x256 1 opacity, Done. (0.095s)
# image 375/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4fc5d350c335.png: 256x256 1 opacity, Done. (0.095s)
# image 376/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/4ff7b31b3269.png: 256x256 2 opacitys, Done. (0.096s)
# image 377/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/501a1477a60f.png: 256x256 Done. (0.093s)
# image 378/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/506dca9ef41f.png: 256x256 Done. (0.093s)
# image 379/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/507b3c3bac7c.png: 256x256 1 opacity, Done. (0.094s)
# image 380/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/50804b6043ac.png: 256x256 1 opacity, Done. (0.093s)
# image 381/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/50903e9be6fd.png: 256x256 2 opacitys, Done. (0.094s)
# image 382/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/50d404627d73.png: 256x256 2 opacitys, Done. (0.093s)
# image 383/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/5111b11537d3.png: 256x256 Done. (0.092s)
# image 384/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/5114a63d3977.png: 256x256 2 opacitys, Done. (0.092s)
# image 385/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/51759b5579bc.png: 256x256 Done. (0.093s)
# image 386/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/51bb4235d797.png: 256x256 Done. (0.093s)
# image 387/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/51d72afd2519.png: 256x256 1 opacity, Done. (0.095s)
# image 388/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/524911903bde.png: 256x256 1 opacity, Done. (0.096s)
# image 389/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/529866b29d27.png: 256x256 Done. (0.094s)
# image 390/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/52d9af96139f.png: 256x256 1 opacity, Done. (0.093s)
# image 391/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/5301dfecfce2.png: 256x256 Done. (0.093s)
# image 392/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/5315a92172ef.png: 256x256 2 opacitys, Done. (0.093s)
# image 393/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/532f722fa51d.png: 256x256 2 opacitys, Done. (0.093s)
# image 394/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/533638e04060.png: 256x256 1 opacity, Done. (0.094s)
# image 395/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/53989cc7039c.png: 256x256 1 opacity, Done. (0.095s)
# image 396/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/53d8f531e0a1.png: 256x256 Done. (0.094s)
# image 397/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/54155a058e38.png: 256x256 Done. (0.096s)
# image 398/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/5458c3cd03a3.png: 256x256 2 opacitys, Done. (0.096s)
# image 399/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/54d8b82f1ced.png: 256x256 Done. (0.094s)
# image 400/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/54f912577306.png: 256x256 Done. (0.094s)
# image 401/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/558cf3abe42d.png: 256x256 1 opacity, Done. (0.097s)
# image 402/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/55eac3fc31fd.png: 256x256 Done. (0.095s)
# image 403/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/5613f35bd348.png: 256x256 2 opacitys, Done. (0.095s)
# image 404/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/56c506249be2.png: 256x256 2 opacitys, Done. (0.095s)
# image 405/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/56e3ae675ecc.png: 256x256 2 opacitys, Done. (0.095s)
# image 406/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/57675376af04.png: 256x256 Done. (0.094s)
# image 407/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/576bb6054ad3.png: 256x256 Done. (0.095s)
# image 408/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/57e688a7b16a.png: 256x256 Done. (0.095s)
# image 409/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/57f7c8ba8acb.png: 256x256 1 opacity, Done. (0.095s)
# image 410/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/5807a187f396.png: 256x256 2 opacitys, Done. (0.097s)
# image 411/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/583afb74d9ed.png: 256x256 Done. (0.096s)
# ...
# image 1085/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e0d61af446a3.png: 256x256 1 opacity, Done. (0.093s)
# image 1086/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e0ea12e9db87.png: 256x256 1 opacity, Done. (0.093s)
# image 1087/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e0eddccff7d7.png: 256x256 1 opacity, Done. (0.092s)
# image 1088/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e0f4c2ea7603.png: 256x256 Done. (0.093s)
# image 1089/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e11d1185331b.png: 256x256 1 opacity, Done. (0.094s)
# image 1090/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e17affefd696.png: 256x256 Done. (0.094s)
# image 1091/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e2080f0e0731.png: 256x256 Done. (0.094s)
# image 1092/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e24233b0b286.png: 256x256 3 opacitys, Done. (0.096s)
# image 1093/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e24ca1d34bb2.png: 256x256 1 opacity, Done. (0.094s)
# image 1094/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e295ff156bbc.png: 256x256 1 opacity, Done. (0.094s)
# image 1095/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e313470893d0.png: 256x256 3 opacitys, Done. (0.095s)
# image 1096/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e350c6a1acbd.png: 256x256 1 opacity, Done. (0.094s)
# image 1097/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e3863ecd41c3.png: 256x256 1 opacity, Done. (0.093s)
# image 1098/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e3ab2d72cac2.png: 256x256 1 opacity, Done. (0.095s)
# image 1099/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e3cfb3330b60.png: 256x256 1 opacity, Done. (0.094s)
# image 1100/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e4e410d26ceb.png: 256x256 Done. (0.093s)
# image 1101/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e5087d4dc8ca.png: 256x256 1 opacity, Done. (0.096s)
# image 1102/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e5321c43236c.png: 256x256 1 opacity, Done. (0.095s)
# image 1103/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e545e07a7a06.png: 256x256 Done. (0.094s)
# image 1104/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e563f54f421c.png: 256x256 2 opacitys, Done. (0.092s)
# image 1105/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e590e800f892.png: 256x256 2 opacitys, Done. (0.091s)
# image 1106/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e5ea0d324c34.png: 256x256 2 opacitys, Done. (0.091s)
# image 1107/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e6215d0188e5.png: 256x256 1 opacity, Done. (0.091s)
# image 1108/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e642e9fbb17c.png: 256x256 Done. (0.091s)
# image 1109/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e65bdeabbfb9.png: 256x256 1 opacity, Done. (0.091s)
# image 1110/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e6a05de9cd72.png: 256x256 1 opacity, Done. (0.093s)
# image 1111/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e6f8a7c5875c.png: 256x256 1 opacity, Done. (0.098s)
# image 1112/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e77e6c494060.png: 256x256 Done. (0.141s)
# image 1113/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e7be504cf8e9.png: 256x256 1 opacity, Done. (0.131s)
# image 1114/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e7c3f21a9b8b.png: 256x256 Done. (0.127s)
# image 1115/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e7e4dabc46b7.png: 256x256 2 opacitys, Done. (0.126s)
# image 1116/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e830ffb5a568.png: 256x256 2 opacitys, Done. (0.104s)
# image 1117/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e87a25f68d8c.png: 256x256 2 opacitys, Done. (0.092s)
# image 1118/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e8c95d9d060f.png: 256x256 3 opacitys, Done. (0.092s)
# image 1119/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e96133d06736.png: 256x256 1 opacity, Done. (0.092s)
# image 1120/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/e98098b26a0f.png: 256x256 2 opacitys, Done. (0.093s)
# image 1121/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/ea1dd04c7349.png: 256x256 1 opacity, Done. (0.094s)
# image 1122/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/ea3ab6f3dcad.png: 256x256 1 opacity, Done. (0.095s)
# image 1123/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/ea3d66fd0904.png: 256x256 1 opacity, Done. (0.094s)
# image 1124/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/ea42a66bba4b.png: 256x256 1 opacity, Done. (0.094s)
# image 1125/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/ea56b964075b.png: 256x256 Done. (0.093s)
# image 1126/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/ea684a998f51.png: 256x256 Done. (0.093s)
# image 1127/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/ea85c81c2600.png: 256x256 1 opacity, Done. (0.093s)
# image 1128/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/eb0852368951.png: 256x256 Done. (0.093s)
# image 1129/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/eb26cddff06a.png: 256x256 1 opacity, Done. (0.093s)
# image 1130/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/eb446b336fdf.png: 256x256 Done. (0.093s)
# image 1131/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/eb5282ff3153.png: 256x256 1 opacity, Done. (0.107s)
# image 1132/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/eb693bd6b5db.png: 256x256 2 opacitys, Done. (0.095s)
# image 1133/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/ec31d6a71eeb.png: 256x256 Done. (0.092s)
# image 1134/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/ec93f171f4fd.png: 256x256 Done. (0.091s)
# image 1135/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/ec9fffbd1457.png: 256x256 Done. (0.091s)
# image 1136/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/ecdb5a0dcd17.png: 256x256 Done. (0.090s)
# image 1137/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/ed2e92d5ae24.png: 256x256 2 opacitys, Done. (0.091s)
# image 1138/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/ed77e3dd29ea.png: 256x256 Done. (0.091s)
# image 1139/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/ed9b7e88b259.png: 256x256 Done. (0.091s)
# image 1140/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/ee086fdd5c81.png: 256x256 1 opacity, Done. (0.093s)
# image 1141/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/ee98c5bef21d.png: 256x256 1 opacity, Done. (0.092s)
# image 1142/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/eea28baa7c69.png: 256x256 2 opacitys, Done. (0.095s)
# image 1143/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/ef0a3da0389f.png: 256x256 1 opacity, Done. (0.093s)
# image 1144/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/ef1a73df3463.png: 256x256 Done. (0.094s)
# image 1145/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/ef367099b05f.png: 256x256 Done. (0.093s)
# image 1146/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/ef5a412bf92a.png: 256x256 3 opacitys, Done. (0.094s)
# image 1147/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/ef5b32cf2930.png: 256x256 2 opacitys, Done. (0.095s)
# image 1148/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/efe83e860c17.png: 256x256 1 opacity, Done. (0.096s)
# image 1149/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f01d5caded33.png: 256x256 2 opacitys, Done. (0.094s)
# image 1150/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f043bf82ee4e.png: 256x256 1 opacity, Done. (0.095s)
# image 1151/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f051f146f514.png: 256x256 2 opacitys, Done. (0.095s)
# image 1152/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f0a21386ef18.png: 256x256 Done. (0.093s)
# image 1153/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f0abf0c5cbad.png: 256x256 1 opacity, Done. (0.094s)
# image 1154/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f0d2179664cc.png: 256x256 1 opacity, Done. (0.091s)
# image 1155/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f17ca5bc4d61.png: 256x256 1 opacity, Done. (0.092s)
# image 1156/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f1d6ae8de9dc.png: 256x256 Done. (0.094s)
# image 1157/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f1fb11c067c6.png: 256x256 Done. (0.099s)
# image 1158/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f208dc529d16.png: 256x256 1 opacity, Done. (0.093s)
# image 1159/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f21c0ad4f6c6.png: 256x256 Done. (0.091s)
# image 1160/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f228350bd770.png: 256x256 Done. (0.091s)
# image 1161/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f2633be66b0d.png: 256x256 1 opacity, Done. (0.092s)
# image 1162/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f26705a28681.png: 256x256 Done. (0.093s)
# image 1163/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f2a37ea4c3f3.png: 256x256 Done. (0.093s)
# image 1164/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f30c28a6a8a7.png: 256x256 1 opacity, Done. (0.095s)
# image 1165/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f333a4e102d8.png: 256x256 Done. (0.093s)
# image 1166/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f3545143296a.png: 256x256 Done. (0.093s)
# image 1167/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f36fff73055c.png: 256x256 Done. (0.093s)
# image 1168/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f3728a2aa0e9.png: 256x256 1 opacity, Done. (0.094s)
# image 1169/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f3d975c4ca97.png: 256x256 2 opacitys, Done. (0.093s)
# image 1170/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f420e3696115.png: 256x256 Done. (0.093s)
# image 1171/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f45b99a2e9bb.png: 256x256 2 opacitys, Done. (0.094s)
# image 1172/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f481797c0b37.png: 256x256 1 opacity, Done. (0.093s)
# image 1173/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f5020d2a27d1.png: 256x256 Done. (0.094s)
# image 1174/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f5217eb57e14.png: 256x256 Done. (0.093s)
# image 1175/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f5428f049a02.png: 256x256 Done. (0.092s)
# image 1176/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f55d58936e04.png: 256x256 1 opacity, Done. (0.094s)
# image 1177/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f59a4957542a.png: 256x256 2 opacitys, Done. (0.094s)
# image 1178/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f5b4e8d1c058.png: 256x256 3 opacitys, Done. (0.094s)
# image 1179/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f6293b1c49e2.png: 256x256 1 opacity, Done. (0.095s)
# image 1180/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f6cd7aba6e62.png: 256x256 1 opacity, Done. (0.094s)
# image 1181/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f6d193531784.png: 256x256 1 opacity, Done. (0.093s)
# image 1182/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f76cebb4d35f.png: 256x256 1 opacity, Done. (0.094s)
# image 1183/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f78663a47369.png: 256x256 2 opacitys, Done. (0.093s)
# image 1184/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f78d724cd9af.png: 256x256 Done. (0.093s)
# image 1185/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f7a5935dee5c.png: 256x256 1 opacity, Done. (0.092s)
# image 1186/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f7bb2e09d818.png: 256x256 Done. (0.091s)
# image 1187/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f7cbb88ba1c2.png: 256x256 1 opacity, Done. (0.091s)
# image 1188/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f7d09631e6dd.png: 256x256 1 opacity, Done. (0.092s)
# image 1189/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f80c6d2df74d.png: 256x256 1 opacity, Done. (0.091s)
# image 1190/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f825c4eda7f4.png: 256x256 Done. (0.091s)
# image 1191/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f82f99deaae2.png: 256x256 3 opacitys, Done. (0.091s)
# image 1192/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f83043bab3eb.png: 256x256 1 opacity, Done. (0.093s)
# image 1193/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f873979cc0a8.png: 256x256 Done. (0.091s)
# image 1194/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f87b978285e8.png: 256x256 1 opacity, Done. (0.092s)
# image 1195/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f8e17b1c73ff.png: 256x256 1 opacity, Done. (0.092s)
# image 1196/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f9672a3734f5.png: 256x256 Done. (0.091s)
# image 1197/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f9729a4e5c44.png: 256x256 2 opacitys, Done. (0.091s)
# image 1198/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f972e983e0cd.png: 256x256 3 opacitys, Done. (0.091s)
# image 1199/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/f9d20afa051a.png: 256x256 1 opacity, Done. (0.092s)
# image 1200/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/fa5f8d9acc5e.png: 256x256 Done. (0.091s)
# image 1201/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/fa935d855d4e.png: 256x256 Done. (0.091s)
# image 1202/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/fab7eaa2770f.png: 256x256 1 opacity, Done. (0.091s)
# image 1203/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/fb1e24bf6698.png: 256x256 Done. (0.091s)
# image 1204/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/fb5d173c4c47.png: 256x256 Done. (0.090s)
# image 1205/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/fbce3517cc78.png: 256x256 Done. (0.094s)
# image 1206/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/fc00fda61d7f.png: 256x256 1 opacity, Done. (0.094s)
# image 1207/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/fc2ca834e6c6.png: 256x256 Done. (0.091s)
# image 1208/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/fc612cef0a2b.png: 256x256 2 opacitys, Done. (0.092s)
# image 1209/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/fce103c7c62b.png: 256x256 Done. (0.091s)
# image 1210/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/fd216bc37e84.png: 256x256 Done. (0.091s)
# image 1211/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/fd3f9225e10b.png: 256x256 1 opacity, Done. (0.092s)
# image 1212/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/fd46baeed64d.png: 256x256 Done. (0.092s)
# image 1213/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/fd7ddd30d8dc.png: 256x256 Done. (0.095s)
# image 1214/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/fe2aaee14b5d.png: 256x256 Done. (0.098s)
# image 1215/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/fe41376fa23f.png: 256x256 Done. (0.097s)
# image 1216/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/fe426d79609d.png: 256x256 Done. (0.092s)
# image 1217/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/fed0ecac96cb.png: 256x256 3 opacitys, Done. (0.095s)
# image 1218/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/fee880bc30b5.png: 256x256 Done. (0.094s)
# image 1219/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/ff4cd60f14b7.png: 256x256 Done. (0.093s)
# image 1220/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/ff6ee6ae167b.png: 256x256 Done. (0.094s)
# image 1221/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/ffbeafe30b77.png: 256x256 1 opacity, Done. (0.094s)
# image 1222/1222 /kaggle/tmp/yolov5/../dataset_folds_4/images/valid/ffdc682f7680.png: 256x256 Done. (0.093s)
# Results saved to runs/detect/infer_fold_43
# 773 labels saved to runs/detect/infer_fold_43/labels
# Done. (123.327s)

# %% [markdown]
# # 🚀 Ensembling
#
# Ensembling YOLOv5 models is as easy as calling `python detect.py` and pass in model weights as arguments:
#
# `python detect.py --weights yolov5x.pt yolov5l6.pt --img 640 --source data/images`
#
# You can learn more about ensembling [here](https://github.com/ultralytics/yolov5/issues/318).
#
# ### You can check out my [Submission Covid19](https://www.kaggle.com/ayuraj/submission-covid19) kernel for Ensembling.
