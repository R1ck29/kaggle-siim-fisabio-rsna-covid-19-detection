# %% [markdown]
# This is a starter kernel to train a YOLOv5 model on [SIIM-FISABIO-RSNA COVID-19 Detection](https://www.kaggle.com/c/siim-covid19-detection/overview) dataset. Given an input image the task is to find the region of opacity in the chest  using bounding box coordinates. Check out [Visualize Bounding Boxes Interactively](https://www.kaggle.com/ayuraj/visualize-bounding-boxes-interactively) for interactive bounding box EDA.
#
# ## 🖼️ What is YOLOv5?
#
# YOLO an acronym for 'You only look once', is an object detection algorithm that divides images into a grid system. Each cell in the grid is responsible for detecting objects within itself.
#
# [Ultralytics' YOLOv5](https://ultralytics.com/yolov5) ("You Only Look Once") model family enables real-time object detection with convolutional neural networks.
#
# ## 🦄 What is Weights and Biases?
#
# Weights & Biases (W&B) is a set of machine learning tools that helps you build better models faster. Check out [Experiment Tracking with Weights and Biases](https://www.kaggle.com/ayuraj/experiment-tracking-with-weights-and-biases) to learn more.
# Weights & Biases is directly integrated into YOLOv5, providing experiment metric tracking, model and dataset versioning, rich model prediction visualization, and more.
#
#
# It's a work in progress:
#
# ✔️ Required folder structure. <br>
# ✔️ Bounding box format required for YOLOv5. <br>
# ✔️ **Train** a small YOLOv5 model. <br>
# ✔️ Experiment tracking with W&B. <br>
# ✔️ Proper documentation <br>
# ✔️ Inference <br>
#
# ❌ Model prediction visualization.
#
# ## Results
#
# ### [Check out W&B Run Page $\rightarrow$](https://wandb.ai/ayush-thakur/kaggle-siim-covid/runs/1bk93e3j)
#
# ![img](https://i.imgur.com/quOYtNN.gif)

# %% [markdown]
# # ☀️ Imports and Setup
#
# According to the official [Train Custom Data](https://github.com/ultralytics/yolov5/wiki/Train-Custom-Data) guide, YOLOv5 requires a certain directory structure.
#
# ```
# /parent_folder
#     /dataset
#          /images
#          /labels
#     /yolov5
# ```
#
# * We thus will create a `/tmp` directory. <br>
# * Download YOLOv5 repository and pip install the required dependencies. <br>
# * Install the latest version of W&B and login with your wandb account. You can create your free W&B account [here](https://wandb.ai/site).

# %%
# %cd ../
# !mkdir tmp
# %cd tmp

# %%
# Download YOLOv5
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# # Install dependencies
# %pip install -qr requirements.txt  # install dependencies

# %cd ../
import torch
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.7.1+cu101 (GeForce RTX 2080 Ti)

# %%
# Install W&B 
# !pip install -q --upgrade wandb
# Login 
import wandb
wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: r1ck (use `wandb login --relogin` to force relogin)
# True

# %%
# Necessary/extra dependencies. 
import os
import gc
import cv2
import numpy as np
import pandas as pd
from tqdm import tqdm
from shutil import copyfile
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

#customize iPython writefile so we can write variables
from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))

# %% [markdown]
# # 🦆 Hyperparameters

# %%
# TRAIN_PATH = 'input/siim-covid19-resized-to-256px-jpg/train/'
TRAIN_PATH = '../input/train/'

IMG_SIZE = 512 #256
BATCH_SIZE = 16
EPOCHS = 200

# %% [markdown]
# # 🔨 Prepare Dataset
#
# This is the most important section when it comes to training an object detector with YOLOv5. The directory structure, bounding box format, etc must be in the correct order. This section builds every piece needed to train a YOLOv5 model.
#
# I am using [xhlulu's](https://www.kaggle.com/xhlulu) resized dataset. The uploaded 256x256 Kaggle dataset is [here](https://www.kaggle.com/xhlulu/siim-covid19-resized-to-256px-jpg). Find other image resolutions [here](https://www.kaggle.com/c/siim-covid19-detection/discussion/239918).
#
# * Create train-validation split. <br>
# * Create required `/dataset` folder structure and more the images to that folder. <br>
# * Create `data.yaml` file needed to train the model. <br>
# * Create bounding box coordinates in the required YOLO format.

# %%
# !ls

# %%
# Everything is done from /kaggle directory.
# %cd ../

# Load image level csv file
df = pd.read_csv('../input/train_image_level.csv')

# Modify values in the id column
df['id'] = df.apply(lambda row: row.id.split('_')[0], axis=1)
# Add absolute path
df['path'] = df.apply(lambda row: TRAIN_PATH+row.id+'.png', axis=1)
# Get image level labels
df['image_level'] = df.apply(lambda row: row.label.split(' ')[0], axis=1)

df.head(5)
# Out:
#              id                                              boxes  \
# 0  000a312787f2  [{'x': 789.28836, 'y': 582.43035, 'width': 102...
# 1  000c3a3f293f                                                NaN
# 2  0012ff7358bc  [{'x': 677.42216, 'y': 197.97662, 'width': 867...
# 3  001398f4ff4f  [{'x': 2729, 'y': 2181.33331, 'width': 948.000...
# 4  001bd15d1891  [{'x': 623.23328, 'y': 1050, 'width': 714, 'he...
#
#                                                label StudyInstanceUID  \
# 0  opacity 1 789.28836 582.43035 1815.94498 2499....     5776db0cec75
# 1                                     none 1 0 0 1 1     ff0879eb20ed
# 2  opacity 1 677.42216 197.97662 1545.21983 1197....     9d514ce429a7
# 3    opacity 1 2729 2181.33331 3677.00012 2785.33331     28dddc8559b2
# 4  opacity 1 623.23328 1050 1337.23328 2156 opaci...     dfd9fdd85a3e
#
#                               path image_level
# 0  ../input/train/000a312787f2.png     opacity
# 1  ../input/train/000c3a3f293f.png        none
# 2  ../input/train/0012ff7358bc.png     opacity
# 3  ../input/train/001398f4ff4f.png     opacity
# 4  ../input/train/001bd15d1891.png     opacity

# %%
# Load meta.csv file
# Original dimensions are required to scale the bounding box coordinates appropriately.
# meta_df = pd.read_csv('input/siim-covid19-resized-to-256px-jpg/meta.csv')
# meta_df = pd.read_csv('../input/meta.csv')

# train_meta_df = meta_df.loc[meta_df.split == 'train']
# train_meta_df = train_meta_df.drop('split', axis=1)
# train_meta_df.columns = ['id', 'dim0', 'dim1']

# train_meta_df.head(2)

# %%
# # Merge both the dataframes
# df = df.merge(train_meta_df, on='id',how="left")
# df.head()

# %%
# df.columns

# %%
# df.to_csv('../input/train_v1.csv', index=False)

# %%
df = pd.read_csv('../input/train_v1.csv')

# %%
#Numeric Label and removed _study
train_study_level = pd.read_csv("../input/train_study_level.csv")
train_study_level
# Out:
#                       id  Negative for Pneumonia  Typical Appearance  \
# 0     00086460a852_study                       0                   1
# 1     000c9c05fd14_study                       0                   0
# 2     00292f8c37bd_study                       1                   0
# 3     005057b3f880_study                       1                   0
# 4     0051d9b12e72_study                       0                   0
# ...                  ...                     ...                 ...
# 6049  ffcb4630f46f_study                       0                   1
# 6050  ffe4d6e8fbb0_study                       0                   1
# 6051  ffe94fcb14fa_study                       0                   1
# 6052  ffebf1ef4a9c_study                       0                   1
# 6053  fff649d65f62_study                       0                   1
#
#       Indeterminate Appearance  Atypical Appearance
# 0                            0                    0
# 1                            0                    1
# 2                            0                    0
# 3                            0                    0
# 4                            0                    1
# ...                        ...                  ...
# 6049                         0                    0
# 6050                         0                    0
# 6051                         0                    0
# 6052                         0                    0
# 6053                         0                    0
#
# [6054 rows x 5 columns]

# %%
# train_study_level.id = train_study_level.id.str[:-6]
train_study_level["class_id"] = train_study_level.apply(lambda l: np.argmax(l.values[1:]),axis=1)
train_study_level.rename(columns={'id':'study_id'}, inplace=True)
train_study_level
# Out:
#                 study_id  Negative for Pneumonia  Typical Appearance  \
# 0     00086460a852_study                       0                   1
# 1     000c9c05fd14_study                       0                   0
# 2     00292f8c37bd_study                       1                   0
# 3     005057b3f880_study                       1                   0
# 4     0051d9b12e72_study                       0                   0
# ...                  ...                     ...                 ...
# 6049  ffcb4630f46f_study                       0                   1
# 6050  ffe4d6e8fbb0_study                       0                   1
# 6051  ffe94fcb14fa_study                       0                   1
# 6052  ffebf1ef4a9c_study                       0                   1
# 6053  fff649d65f62_study                       0                   1
#
#       Indeterminate Appearance  Atypical Appearance  class_id
# 0                            0                    0         1
# 1                            0                    1         3
# 2                            0                    0         0
# 3                            0                    0         0
# 4                            0                    1         3
# ...                        ...                  ...       ...
# 6049                         0                    0         1
# 6050                         0                    0         1
# 6051                         0                    0         1
# 6052                         0                    0         1
# 6053                         0                    0         1
#
# [6054 rows x 6 columns]

# %%
train_study_level['Negative for Pneumonia'].value_counts()
# Out:
# 0    4378
# 1    1676
# Name: Negative for Pneumonia, dtype: int64

# %%
train_study_level['Typical Appearance'].value_counts()
# Out:
# 0    3199
# 1    2855
# Name: Typical Appearance, dtype: int64

# %%
train_study_level.class_id.value_counts()
# Out:
# 1    2855
# 0    1676
# 2    1049
# 3     474
# Name: class_id, dtype: int64

# %%
train_study_level
# Out:
#                 study_id  Negative for Pneumonia  Typical Appearance  \
# 0     00086460a852_study                       0                   1
# 1     000c9c05fd14_study                       0                   0
# 2     00292f8c37bd_study                       1                   0
# 3     005057b3f880_study                       1                   0
# 4     0051d9b12e72_study                       0                   0
# ...                  ...                     ...                 ...
# 6049  ffcb4630f46f_study                       0                   1
# 6050  ffe4d6e8fbb0_study                       0                   1
# 6051  ffe94fcb14fa_study                       0                   1
# 6052  ffebf1ef4a9c_study                       0                   1
# 6053  fff649d65f62_study                       0                   1
#
#       Indeterminate Appearance  Atypical Appearance  class_id
# 0                            0                    0         1
# 1                            0                    1         3
# 2                            0                    0         0
# 3                            0                    0         0
# 4                            0                    1         3
# ...                        ...                  ...       ...
# 6049                         0                    0         1
# 6050                         0                    0         1
# 6051                         0                    0         1
# 6052                         0                    0         1
# 6053                         0                    0         1
#
# [6054 rows x 6 columns]

# %%
# train_study_level.to_csv('../input/train_classification_v1.csv', index=False)

# %%
df.image_level.value_counts()
# Out:
# opacity    4294
# none       2040
# Name: image_level, dtype: int64

# %%
df
# Out:
#                 id                                              boxes  \
# 0     000a312787f2  [{'x': 789.28836, 'y': 582.43035, 'width': 102...
# 1     000c3a3f293f                                                NaN
# 2     0012ff7358bc  [{'x': 677.42216, 'y': 197.97662, 'width': 867...
# 3     001398f4ff4f  [{'x': 2729, 'y': 2181.33331, 'width': 948.000...
# 4     001bd15d1891  [{'x': 623.23328, 'y': 1050, 'width': 714, 'he...
# ...            ...                                                ...
# 6329  ffcc6edd9445                                                NaN
# 6330  ffd91a2c4ca0                                                NaN
# 6331  ffd9b6cf2961  [{'x': 2197.38566, 'y': 841.07361, 'width': 31...
# 6332  ffdc682f7680  [{'x': 2729.27083, 'y': 332.26044, 'width': 14...
# 6333  ffe942c8655f  [{'x': 208.86463, 'y': 91.53448, 'width': 450....
#
#                                                   label StudyInstanceUID  \
# 0     opacity 1 789.28836 582.43035 1815.94498 2499....     5776db0cec75
# 1                                        none 1 0 0 1 1     ff0879eb20ed
# 2     opacity 1 677.42216 197.97662 1545.21983 1197....     9d514ce429a7
# 3       opacity 1 2729 2181.33331 3677.00012 2785.33331     28dddc8559b2
# 4     opacity 1 623.23328 1050 1337.23328 2156 opaci...     dfd9fdd85a3e
# ...                                                 ...              ...
# 6329                                     none 1 0 0 1 1     7e6c68462e06
# 6330                                     none 1 0 0 1 1     8332bdaddb6e
# 6331  opacity 1 2197.38566 841.07361 2513.80265 1292...     7eed9af03814
# 6332  opacity 1 2729.27083 332.26044 4225.52099 2936...     a0cb0b96fb3d
# 6333  opacity 1 208.86463 91.53448 659.8321 719.5892...     7d82d53204b8
#
#                                  path image_level
# 0     ../input/train/000a312787f2.png     opacity
# 1     ../input/train/000c3a3f293f.png        none
# 2     ../input/train/0012ff7358bc.png     opacity
# 3     ../input/train/001398f4ff4f.png     opacity
# 4     ../input/train/001bd15d1891.png     opacity
# ...                               ...         ...
# 6329  ../input/train/ffcc6edd9445.png        none
# 6330  ../input/train/ffd91a2c4ca0.png        none
# 6331  ../input/train/ffd9b6cf2961.png     opacity
# 6332  ../input/train/ffdc682f7680.png     opacity
# 6333  ../input/train/ffe942c8655f.png     opacity
#
# [6334 rows x 6 columns]

# %%
# df_2 = pd.merge(df, train_study_level, left_on='StudyInstanceUID', right_on='study_id', how='outer')
df_2 = pd.merge(train_study_level, df, left_on='study_id', right_on='StudyInstanceUID', how='inner')

# %%
df_2
# Out:
#           study_id  Negative for Pneumonia  Typical Appearance  \
# 0     00086460a852                       0                   1
# 1     000c9c05fd14                       0                   0
# 2     00292f8c37bd                       1                   0
# 3     005057b3f880                       1                   0
# 4     0051d9b12e72                       0                   0
# ...            ...                     ...                 ...
# 6329  ffcb4630f46f                       0                   1
# 6330  ffe4d6e8fbb0                       0                   1
# 6331  ffe94fcb14fa                       0                   1
# 6332  ffebf1ef4a9c                       0                   1
# 6333  fff649d65f62                       0                   1
#
#       Indeterminate Appearance  Atypical Appearance  class_id            id  \
# 0                            0                    0         1  65761e66de9f
# 1                            0                    1         3  51759b5579bc
# 2                            0                    0         0  f6293b1c49e2
# 3                            0                    0         0  3019399c31f4
# 4                            0                    1         3  bb4b1da810f3
# ...                        ...                  ...       ...           ...
# 6329                         0                    0         1  84ed5f7f71bf
# 6330                         0                    0         1  e6215d0188e5
# 6331                         0                    0         1  7d27b1bb3987
# 6332                         0                    0         1  52478e480a15
# 6333                         0                    0         1  8a80cfa63a23
#
#                                                   boxes  \
# 0     [{'x': 720.65215, 'y': 636.51048, 'width': 332...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     [{'x': 812.54698, 'y': 1376.41291, 'width': 62...
# ...                                                 ...
# 6329  [{'x': 1721.27651, 'y': 974.09667, 'width': 12...
# 6330  [{'x': 364.93056, 'y': 870.04017, 'width': 731...
# 6331  [{'x': 28.48292, 'y': 828.48474, 'width': 1116...
# 6332  [{'x': 425.81211, 'y': 424.86147, 'width': 528...
# 6333  [{'x': 949.33503, 'y': 1495.82807, 'width': 71...
#
#                                                   label StudyInstanceUID  \
# 0     opacity 1 720.65215 636.51048 1052.84563 1284....     00086460a852
# 1                                        none 1 0 0 1 1     000c9c05fd14
# 2                                        none 1 0 0 1 1     00292f8c37bd
# 3                                        none 1 0 0 1 1     005057b3f880
# 4     opacity 1 812.54698 1376.41291 1435.14793 1806...     0051d9b12e72
# ...                                                 ...              ...
# 6329  opacity 1 1721.27651 974.09667 2999.21998 2681...     ffcb4630f46f
# 6330  opacity 1 364.93056 870.04017 1096.13908 2053....     ffe4d6e8fbb0
# 6331  opacity 1 28.48292 828.48474 1145.01081 2296.7...     ffe94fcb14fa
# 6332  opacity 1 425.81211 424.86147 953.95118 1579.3...     ffebf1ef4a9c
# 6333  opacity 1 949.33503 1495.82807 1666.45264 2784...     fff649d65f62
#
#                                  path image_level
# 0     ../input/train/65761e66de9f.png     opacity
# 1     ../input/train/51759b5579bc.png        none
# 2     ../input/train/f6293b1c49e2.png        none
# 3     ../input/train/3019399c31f4.png        none
# 4     ../input/train/bb4b1da810f3.png     opacity
# ...                               ...         ...
# 6329  ../input/train/84ed5f7f71bf.png     opacity
# 6330  ../input/train/e6215d0188e5.png     opacity
# 6331  ../input/train/7d27b1bb3987.png     opacity
# 6332  ../input/train/52478e480a15.png     opacity
# 6333  ../input/train/8a80cfa63a23.png     opacity
#
# [6334 rows x 12 columns]

# %%
df_2.class_id.isna().sum()
# Out:
# 0

# %%
df_2.id.nunique()
# Out:
# 6334

# %%
df_2.study_id.nunique()
# Out:
# 6054

# %%
df_2[df_2.id.duplicated()]
# Out:
# Empty DataFrame
# Columns: [study_id, Negative for Pneumonia, Typical Appearance, Indeterminate Appearance, Atypical Appearance, class_id, id, boxes, label, StudyInstanceUID, path, image_level]
# Index: []

# %%
df_2[df_2['study_id']=='00f9e183938e']
# Out:
#         study_id  Negative for Pneumonia  Typical Appearance  \
# 16  00f9e183938e                       0                   0
# 17  00f9e183938e                       0                   0
#
#     Indeterminate Appearance  Atypical Appearance  class_id            id  \
# 16                         0                    1         3  6534a837497d
# 17                         0                    1         3  74077a8e3b7c
#
#                                                 boxes  \
# 16                                                NaN
# 17  [{'x': 2175.24285, 'y': 1123.72368, 'width': 4...
#
#                                                 label StudyInstanceUID  \
# 16                                     none 1 0 0 1 1     00f9e183938e
# 17  opacity 1 2175.24285 1123.72368 2607.50603 162...     00f9e183938e
#
#                                path image_level
# 16  ../input/train/6534a837497d.png        none
# 17  ../input/train/74077a8e3b7c.png     opacity

# %%
duplicate_study_id = df_2[df_2.duplicated(['study_id'])]

# %%
duplicate_study_id
# Out:
#           study_id  Negative for Pneumonia  Typical Appearance  \
# 17    00f9e183938e                       0                   0
# 26    0142feaef82f                       0                   0
# 79    0369e0385796                       0                   1
# 136   061d2ddaddd1                       0                   0
# 139   066b12d875eb                       0                   0
# ...            ...                     ...                 ...
# 6204  fa9ea207e240                       0                   1
# 6212  fae06a05819a                       0                   1
# 6242  fc45007f145a                       0                   1
# 6275  fd92c6f2b2e6                       1                   0
# 6329  ffcb4630f46f                       0                   1
#
#       Indeterminate Appearance  Atypical Appearance  class_id            id  \
# 17                           0                    1         3  74077a8e3b7c
# 26                           1                    0         2  f5451a98d684
# 79                           0                    0         1  ea2117b53323
# 136                          1                    0         2  67ea53f37acf
# 139                          1                    0         2  eea3a910fa9e
# ...                        ...                  ...       ...           ...
# 6204                         0                    0         1  b7f123e4992f
# 6212                         0                    0         1  ba375ad92c5f
# 6242                         0                    0         1  8a38c00672d5
# 6275                         0                    0         0  e6cc65d9de1d
# 6329                         0                    0         1  84ed5f7f71bf
#
#                                                   boxes  \
# 17    [{'x': 2175.24285, 'y': 1123.72368, 'width': 4...
# 26                                                  NaN
# 79                                                  NaN
# 136   [{'x': 1996.08742, 'y': 981.46708, 'width': 61...
# 139                                                 NaN
# ...                                                 ...
# 6204  [{'x': 279.76393, 'y': 281.41593, 'width': 109...
# 6212                                                NaN
# 6242                                                NaN
# 6275                                                NaN
# 6329  [{'x': 1721.27651, 'y': 974.09667, 'width': 12...
#
#                                                   label StudyInstanceUID  \
# 17    opacity 1 2175.24285 1123.72368 2607.50603 162...     00f9e183938e
# 26                                       none 1 0 0 1 1     0142feaef82f
# 79                                       none 1 0 0 1 1     0369e0385796
# 136   opacity 1 1996.08742 981.46708 2614.45583 1726...     061d2ddaddd1
# 139                                      none 1 0 0 1 1     066b12d875eb
# ...                                                 ...              ...
# 6204  opacity 1 279.76393 281.41593 1374.15922 2069....     fa9ea207e240
# 6212                                     none 1 0 0 1 1     fae06a05819a
# 6242                                     none 1 0 0 1 1     fc45007f145a
# 6275                                     none 1 0 0 1 1     fd92c6f2b2e6
# 6329  opacity 1 1721.27651 974.09667 2999.21998 2681...     ffcb4630f46f
#
#                                  path image_level
# 17    ../input/train/74077a8e3b7c.png     opacity
# 26    ../input/train/f5451a98d684.png        none
# 79    ../input/train/ea2117b53323.png        none
# 136   ../input/train/67ea53f37acf.png     opacity
# 139   ../input/train/eea3a910fa9e.png        none
# ...                               ...         ...
# 6204  ../input/train/b7f123e4992f.png     opacity
# 6212  ../input/train/ba375ad92c5f.png        none
# 6242  ../input/train/8a38c00672d5.png        none
# 6275  ../input/train/e6cc65d9de1d.png        none
# 6329  ../input/train/84ed5f7f71bf.png     opacity
#
# [280 rows x 12 columns]

# %%
duplicate_study_id[duplicate_study_id.image_level=='none']
# Out:
#           study_id  Negative for Pneumonia  Typical Appearance  \
# 26    0142feaef82f                       0                   0
# 79    0369e0385796                       0                   1
# 139   066b12d875eb                       0                   0
# 218   0949b847bda6                       0                   1
# 309   0d33fb757a01                       0                   1
# ...            ...                     ...                 ...
# 6119  f689f3fba17a                       0                   1
# 6126  f6ffe212deeb                       1                   0
# 6212  fae06a05819a                       0                   1
# 6242  fc45007f145a                       0                   1
# 6275  fd92c6f2b2e6                       1                   0
#
#       Indeterminate Appearance  Atypical Appearance  class_id            id  \
# 26                           1                    0         2  f5451a98d684
# 79                           0                    0         1  ea2117b53323
# 139                          1                    0         2  eea3a910fa9e
# 218                          0                    0         1  e60a47d36e62
# 309                          0                    0         1  9b1de1c45491
# ...                        ...                  ...       ...           ...
# 6119                         0                    0         1  a323f1604ae2
# 6126                         0                    0         0  21518ca15050
# 6212                         0                    0         1  ba375ad92c5f
# 6242                         0                    0         1  8a38c00672d5
# 6275                         0                    0         0  e6cc65d9de1d
#
#      boxes           label StudyInstanceUID                             path  \
# 26     NaN  none 1 0 0 1 1     0142feaef82f  ../input/train/f5451a98d684.png
# 79     NaN  none 1 0 0 1 1     0369e0385796  ../input/train/ea2117b53323.png
# 139    NaN  none 1 0 0 1 1     066b12d875eb  ../input/train/eea3a910fa9e.png
# 218    NaN  none 1 0 0 1 1     0949b847bda6  ../input/train/e60a47d36e62.png
# 309    NaN  none 1 0 0 1 1     0d33fb757a01  ../input/train/9b1de1c45491.png
# ...    ...             ...              ...                              ...
# 6119   NaN  none 1 0 0 1 1     f689f3fba17a  ../input/train/a323f1604ae2.png
# 6126   NaN  none 1 0 0 1 1     f6ffe212deeb  ../input/train/21518ca15050.png
# 6212   NaN  none 1 0 0 1 1     fae06a05819a  ../input/train/ba375ad92c5f.png
# 6242   NaN  none 1 0 0 1 1     fc45007f145a  ../input/train/8a38c00672d5.png
# 6275   NaN  none 1 0 0 1 1     fd92c6f2b2e6  ../input/train/e6cc65d9de1d.png
#
#      image_level
# 26          none
# 79          none
# 139         none
# 218         none
# 309         none
# ...          ...
# 6119        none
# 6126        none
# 6212        none
# 6242        none
# 6275        none
#
# [191 rows x 12 columns]

# %%
df_2.class_id.value_counts()
# Out:
# 1    3007
# 0    1736
# 2    1108
# 3     483
# Name: class_id, dtype: int64

# %%
# df_2.to_csv('../input/train_v1.csv', index=False)

# %% [markdown]
# ## 🍘 Train-validation split

# %%
# Create train and validation split.
train_df, valid_df = train_test_split(df, test_size=0.2, random_state=42, stratify=df.image_level.values)

train_df.loc[:, 'split'] = 'train'
valid_df.loc[:, 'split'] = 'valid'

df = pd.concat([train_df, valid_df]).reset_index(drop=True)
# Out:
# /home/rick/.pyenv/versions/3.8.2/envs/dl_pytorch/lib/python3.8/site-packages/pandas/core/indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/rick/.pyenv/versions/3.8.2/envs/dl_pytorch/lib/python3.8/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
print(f'Size of dataset: {len(df)}, training images: {len(train_df)}. validation images: {len(valid_df)}')
# Out:
# Size of dataset: 6334, training images: 5067. validation images: 1267

# %% [markdown]
# ## 🍚 Prepare Required Folder Structure
#
# The required folder structure for the dataset directory is:
#
# ```
# /parent_folder
#     /dataset
#          /images
#              /train
#              /val
#          /labels
#              /train
#              /val
#     /yolov5
# ```
#
# Note that I have named the directory `covid`.

# %%
os.makedirs('../tmp/covid/images/train', exist_ok=True)
os.makedirs('../tmp/covid/images/valid', exist_ok=True)

os.makedirs('../tmp/covid/labels/train', exist_ok=True)
os.makedirs('../tmp/covid/labels/valid', exist_ok=True)

! ls tmp/covid/images
# Out:
# ls: cannot access 'tmp/covid/images': No such file or directory

# %%
# Move the images to relevant split folder.
for i in tqdm(range(len(df))):
    row = df.loc[i]
    if row.split == 'train':
        copyfile(row.path, f'../tmp/covid/images/train/{row.id}.jpg')
    else:
        copyfile(row.path, f'../tmp/covid/images/valid/{row.id}.jpg')
# Out:
# 100%|██████████| 6334/6334 [00:07<00:00, 884.56it/s]

# %% [markdown]
# ## 🍜 Create `.YAML` file
#
# The `data.yaml`, is the dataset configuration file that defines
#
# 1. an "optional" download command/URL for auto-downloading,
# 2. a path to a directory of training images (or path to a *.txt file with a list of training images),
# 3. a path to a directory of validation images (or path to a *.txt file with a list of validation images),
# 4. the number of classes,
# 5. a list of class names.
#
# > 📍 Important: In this competition, each image can either belong to `opacity` or `none` image-level labels. That's why I have  used the number of classes, `nc` to be 2. YOLOv5 automatically handles the images without any bounding box coordinates.
#
# > 📍 Note: The `data.yaml` is created in the `yolov5/data` directory as required.

# %%
# Create .yaml file 
import yaml

data_yaml = dict(
    train = '../../tmp/covid/images/train',
    val = '../../tmp/covid/images/valid',
    nc = 2,
    names = ['none', 'opacity']
)

# Note that I am creating the file in the yolov5/data/ directory.
with open('../src/yolov5/data/data.yaml', 'w') as outfile:
    yaml.dump(data_yaml, outfile, default_flow_style=True)
    
# %cat ../src/yolov5/data/data.yaml
# Out:
# {names: [none, opacity], nc: 2, train: ../../tmp/covid/images/train, val: ../../tmp/covid/images/valid}

# %% [markdown]
# ## 🍮 Prepare Bounding Box Coordinated for YOLOv5
#
# For every image with **bounding box(es)** a `.txt` file with the same name as the image will be created in the format shown below:
#
# * One row per object. <br>
# * Each row is class `x_center y_center width height format`. <br>
# * Box coordinates must be in normalized xywh format (from 0 - 1). We can normalize by the boxes in pixels by dividing `x_center` and `width` by image width, and `y_center` and `height` by image height. <br>
# * Class numbers are zero-indexed (start from 0). <br>
#
# > 📍 Note: We don't have to remove the images without bounding boxes from the training or validation sets.

# %%
# Get the raw bounding box by parsing the row value of the label column.
# Ref: https://www.kaggle.com/yujiariyasu/plot-3positive-classes
def get_bbox(row):
    bboxes = []
    bbox = []
    for i, l in enumerate(row.label.split(' ')):
        if (i % 6 == 0) | (i % 6 == 1):
            continue
        bbox.append(float(l))
        if i % 6 == 5:
            bboxes.append(bbox)
            bbox = []  
            
    return bboxes

# Scale the bounding boxes according to the size of the resized image. 
def scale_bbox(row, bboxes):
    # Get scaling factor
    scale_x = IMG_SIZE/row.dim1
    scale_y = IMG_SIZE/row.dim0
    
    scaled_bboxes = []
    for bbox in bboxes:
        x = int(np.round(bbox[0]*scale_x, 4))
        y = int(np.round(bbox[1]*scale_y, 4))
        x1 = int(np.round(bbox[2]*(scale_x), 4))
        y1= int(np.round(bbox[3]*scale_y, 4))

        scaled_bboxes.append([x, y, x1, y1]) # xmin, ymin, xmax, ymax
        
    return scaled_bboxes

# Convert the bounding boxes in YOLO format.
def get_yolo_format_bbox(img_w, img_h, bboxes):
    yolo_boxes = []
    for bbox in bboxes:
        w = bbox[2] - bbox[0] # xmax - xmin
        h = bbox[3] - bbox[1] # ymax - ymin
        xc = bbox[0] + int(np.round(w/2)) # xmin + width/2
        yc = bbox[1] + int(np.round(h/2)) # ymin + height/2
        
        yolo_boxes.append([xc/img_w, yc/img_h, w/img_w, h/img_h]) # x_center y_center width height
    
    return yolo_boxes

# %%
# Prepare the txt files for bounding box
for i in tqdm(range(len(df))):
    row = df.loc[i]
    # Get image id
    img_id = row.id
    # Get split
    split = row.split
    # Get image-level label
    label = row.image_level
    
    if row.split=='train':
        file_name = f'../tmp/covid/labels/train/{row.id}.txt'
    else:
        file_name = f'../tmp/covid/labels/valid/{row.id}.txt'
        
    
    if label=='opacity':
        # Get bboxes
        bboxes = get_bbox(row)
        # Scale bounding boxes
        scale_bboxes = scale_bbox(row, bboxes)
        # Format for YOLOv5
        yolo_bboxes = get_yolo_format_bbox(IMG_SIZE, IMG_SIZE, scale_bboxes)
        
        with open(file_name, 'w') as f:
            for bbox in yolo_bboxes:
                bbox = [1]+bbox
                bbox = [str(i) for i in bbox]
                bbox = ' '.join(bbox)
                f.write(bbox)
                f.write('\n')
# Out:
# 100%|██████████| 6334/6334 [00:02<00:00, 2530.20it/s]

# %% [markdown]
# # 🚅 Train with W&B

# %%
# %cd ../src/yolov5/
# Out:
# /home/rick/Dropbox/python_projects/data_science/Kaggle/siim_covid19/src/yolov5

# %% [markdown]
# ```
# --img {IMG_SIZE} \ # Input image size.
# --batch {BATCH_SIZE} \ # Batch size
# --epochs {EPOCHS} \ # Number of epochs
# --data data.yaml \ # Configuration file
# --weights yolov5s.pt \ # Model name
# --save_period 1\ # Save model after interval
# --project kaggle-siim-covid # W&B project name
# ```

# %%
# !python train.py --img {IMG_SIZE} \
                 --batch {BATCH_SIZE} \
                 --epochs {EPOCHS} \
                 --data data.yaml \
                 --weights yolov5s.pt \
                 --save_period 1\
                 --project kaggle-siim-covid
# Out:
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v5.0-128-g4b52e19 torch 1.7.1+cu101 CUDA:0 (GeForce RTX 2080 Ti, 11019.0625MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='', data='./data/data.yaml', device='', entity=None, epochs=200, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[512, 512], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='exp', noautoanchor=False, nosave=False, notest=False, project='kaggle-siim-covid', quad=False, rect=False, resume=False, save_dir='kaggle-siim-covid/exp3', save_period=1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='yolov5s.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir kaggle-siim-covid', view at http://localhost:6006/
# hyperparameters: lr0=0.01, lrf=0.2, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0
# wandb: Currently logged in as: r1ck (use `wandb login --relogin` to force relogin)
# wandb: Tracking run with wandb version 0.10.31
# wandb: Syncing run exp3
# wandb:  View project at https://wandb.ai/r1ck/kaggle-siim-covid
# wandb:  View run at https://wandb.ai/r1ck/kaggle-siim-covid/runs/1d36t6ft
# wandb: Run data is saved locally in /home/rick/Dropbox/python_projects/data_science/Kaggle/siim_covid19/src/yolov5/wandb/run-20210530_210559-1d36t6ft
# wandb: Run `wandb offline` to turn off syncing.
#
# Overriding model.yaml nc=80 with nc=2
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Focus                     [3, 32, 3]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1    156928  models.common.C3                        [128, 128, 3]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  1    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1    656896  models.common.SPP                       [512, 512, [5, 9, 13]]
#   9                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     18879  models.yolo.Detect                      [2, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model Summary: 283 layers, 7066239 parameters, 7066239 gradients, 16.4 GFLOPS
#
# Transferred 356/362 items from yolov5s.pt
# Scaled weight_decay = 0.0005
# Optimizer groups: 62 .bias, 62 conv.weight, 59 other
# train: Scanning '../../tmp/covid/labels/train' images and labels... 3435 found,
# train: New cache created: ../../tmp/covid/labels/train.cache
# val: Scanning '../../tmp/covid/labels/valid' images and labels... 859 found, 408
# val: New cache created: ../../tmp/covid/labels/valid.cache
# Plotting labels...
#
# autoanchor: Analyzing anchors... anchors/target = 4.78, Best Possible Recall (BPR) = 1.0000
# Image sizes 512 train, 512 test
# Using 8 dataloader workers
# Logging results to kaggle-siim-covid/exp3
# Starting training for 200 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      0/199     2.11G    0.1161   0.02545   0.02879    0.1704        32       512/home/rick/.pyenv/versions/dl_pytorch/lib/python3.8/site-packages/torch/jit/_trace.py:727: UserWarning: The input to trace is already a ScriptModule, tracing it is a no-op. Returning the object as is.
#   warnings.warn(
#      0/199     1.68G   0.07577   0.02518  0.008176    0.1091        26       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.256       0.336       0.182      0.0394
# Images sizes do not match. This will causes images to be display incorrectly in the UI.
# Saving model artifact on epoch  1
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      1/199     2.05G   0.06062   0.02191 0.0008596   0.08339        29       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.201       0.241       0.128      0.0293
# Saving model artifact on epoch  2
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      2/199     2.05G   0.05849   0.02093 0.0007004   0.08012        25       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.353       0.315       0.241       0.062
# Saving model artifact on epoch  3
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      3/199     2.05G   0.05612   0.02065 0.0005111   0.07728        26       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.409       0.378       0.314      0.0847
# Saving model artifact on epoch  4
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      4/199     2.05G   0.05443   0.02066 0.0003035   0.07538        30       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.313       0.354       0.249      0.0684
# Saving model artifact on epoch  5
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      5/199     2.05G   0.05317   0.02054 0.0002497   0.07395        25       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.517       0.429       0.401       0.113
# Saving model artifact on epoch  6
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      6/199     2.05G   0.05249   0.02022 0.0002141   0.07292        34       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.536       0.396       0.394       0.117
# Saving model artifact on epoch  7
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      7/199     2.05G   0.05268    0.0207 0.0001859   0.07357        29       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.433       0.449       0.372       0.112
# Saving model artifact on epoch  8
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      8/199     2.05G   0.05212   0.02048 0.0001715   0.07278        21       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.476       0.452       0.408       0.119
# Saving model artifact on epoch  9
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      9/199     2.05G   0.05178   0.01976 0.0001635   0.07171        19       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.518       0.454       0.432       0.128
# Saving model artifact on epoch  10
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     10/199     2.05G   0.05162   0.02006 0.0001497   0.07183        21       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.496       0.465       0.427       0.122
# Saving model artifact on epoch  11
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     11/199     2.05G   0.05113   0.01994 0.0001417   0.07121        31       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.465       0.487       0.422       0.116
# Saving model artifact on epoch  12
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     12/199     2.05G   0.05121   0.01994 0.0001308   0.07128        23       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.488       0.466       0.435       0.131
# Saving model artifact on epoch  13
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     13/199     2.05G   0.05117    0.0199 0.0001218    0.0712        25       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582        0.57       0.436       0.446       0.125
# Saving model artifact on epoch  14
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     14/199     2.05G    0.0507    0.0201 0.0001185   0.07093        15       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.552       0.423       0.437       0.133
# Saving model artifact on epoch  15
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     15/199     2.05G    0.0502   0.02015 0.0001173   0.07047        22       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.506        0.46       0.419        0.12
# Saving model artifact on epoch  16
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     16/199     2.05G   0.05042   0.01989 0.0001213   0.07044        23       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.503       0.439       0.422       0.116
# Saving model artifact on epoch  17
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     17/199     2.05G   0.05065   0.01973 0.0001179    0.0705        14       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.522       0.451       0.436       0.133
# Saving model artifact on epoch  18
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     18/199     2.05G   0.04998    0.0198 9.727e-05   0.06988        22       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582        0.49       0.487       0.433       0.122
# Saving model artifact on epoch  19
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     19/199     2.05G   0.04977   0.01949 0.0001041   0.06936        30       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.466       0.475       0.422       0.123
# Saving model artifact on epoch  20
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     20/199     2.05G   0.04983   0.01959 0.0001052   0.06952        31       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.475       0.469       0.425        0.13
# Saving model artifact on epoch  21
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     21/199     2.05G   0.04991   0.01955 0.0001044   0.06957        26       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.474        0.48       0.436       0.133
# Saving model artifact on epoch  22
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     22/199     2.05G   0.04958   0.01937 9.978e-05   0.06905        27       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.556       0.468       0.464       0.141
# Saving model artifact on epoch  23
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     23/199     2.05G   0.04972   0.01947 9.747e-05   0.06928        24       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.549       0.469       0.471        0.14
# Saving model artifact on epoch  24
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     24/199     2.05G   0.04955    0.0198  9.83e-05   0.06945        25       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.543       0.477       0.464       0.135
# Saving model artifact on epoch  25
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     25/199     2.05G    0.0493   0.01955 9.273e-05   0.06894        25       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.515       0.482       0.444       0.134
# Saving model artifact on epoch  26
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     26/199     2.05G   0.04903   0.01963 9.072e-05   0.06875        20       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582        0.57       0.468        0.46       0.136
# Saving model artifact on epoch  27
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     27/199     2.05G   0.04922   0.01996 9.156e-05   0.06928        24       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.514       0.498       0.456       0.138
# Saving model artifact on epoch  28
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     28/199     2.05G   0.04924   0.01964 9.083e-05   0.06896        22       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.505       0.497       0.439       0.129
# Saving model artifact on epoch  29
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     29/199     2.05G   0.04885   0.01931 8.978e-05   0.06825        23       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.566       0.443       0.439        0.13
# Saving model artifact on epoch  30
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     30/199     2.05G   0.04892    0.0197 8.379e-05    0.0687        26       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.537       0.461       0.445       0.131
# Saving model artifact on epoch  31
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     31/199     2.05G    0.0489   0.01976 8.836e-05   0.06875        21       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.493       0.466       0.432       0.123
# Saving model artifact on epoch  32
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     32/199     2.05G   0.04822    0.0195 8.439e-05   0.06781        34       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.479       0.498       0.436       0.133
# Saving model artifact on epoch  33
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     33/199     2.05G   0.04854   0.01983 8.413e-05   0.06845        10       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.565       0.457       0.463       0.139
# Saving model artifact on epoch  34
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     34/199     2.05G   0.04824   0.01962 7.934e-05   0.06793        31       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.519        0.43       0.425       0.127
# Saving model artifact on epoch  35
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     35/199     2.05G   0.04822    0.0197 7.718e-05     0.068        24       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.506       0.517       0.463       0.136
# Saving model artifact on epoch  36
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     36/199     2.05G   0.04807   0.01945 8.078e-05   0.06761        16       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.498       0.502       0.456       0.137
# Saving model artifact on epoch  37
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     37/199     2.05G   0.04826   0.01957  7.67e-05   0.06791        23       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.513       0.486       0.448       0.139
# Saving model artifact on epoch  38
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     38/199     2.05G    0.0476    0.0195 7.856e-05   0.06718        23       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582        0.56       0.414       0.423       0.123
# Saving model artifact on epoch  39
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     39/199     2.05G   0.04814   0.01963 7.895e-05   0.06786        17       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.545       0.482       0.452        0.14
# Saving model artifact on epoch  40
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     40/199     2.05G   0.04765   0.01964 7.635e-05   0.06737        21       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.497        0.44       0.416        0.12
# Saving model artifact on epoch  41
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     41/199     2.05G   0.04762    0.0192 7.405e-05    0.0669        15       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.502       0.469       0.434        0.13
# Saving model artifact on epoch  42
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     42/199     2.05G   0.04752   0.01984  7.22e-05   0.06743        27       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582        0.54        0.46       0.443       0.131
# Saving model artifact on epoch  43
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     43/199     2.05G   0.04758   0.01924 7.446e-05   0.06689        19       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.463       0.446        0.41       0.117
# Saving model artifact on epoch  44
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     44/199     2.05G   0.04764    0.0198 7.294e-05   0.06751        24       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.532        0.47       0.448       0.134
# Saving model artifact on epoch  45
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     45/199     2.05G   0.04705   0.01918 7.891e-05   0.06631        21       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.508       0.501       0.453       0.137
# Saving model artifact on epoch  46
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     46/199     2.05G   0.04698   0.01952 7.001e-05   0.06658        20       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.539        0.48        0.45       0.138
# Saving model artifact on epoch  47
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     47/199     2.05G   0.04721   0.01939 7.362e-05   0.06667        30       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582         0.5       0.479       0.439       0.133
# Saving model artifact on epoch  48
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     48/199     2.05G   0.04715   0.01927 7.131e-05   0.06649        27       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.508       0.472       0.432       0.134
# Saving model artifact on epoch  49
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     49/199     2.05G   0.04708   0.01912 6.644e-05   0.06627        19       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.524       0.475       0.449       0.138
# Saving model artifact on epoch  50
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     50/199     2.05G   0.04696   0.01947 6.825e-05    0.0665        36       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582        0.57       0.463        0.46       0.141
# Saving model artifact on epoch  51
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     51/199     2.05G   0.04676   0.01931  6.41e-05   0.06613        28       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.523       0.494       0.459       0.142
# Saving model artifact on epoch  52
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     52/199     2.05G   0.04684    0.0196 6.283e-05   0.06651        23       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.546       0.474       0.448       0.137
# Saving model artifact on epoch  53
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     53/199     2.05G   0.04699   0.01918 6.839e-05   0.06624        24       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.491       0.495       0.442       0.135
# Saving model artifact on epoch  54
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     54/199     2.05G   0.04693   0.01928 6.831e-05   0.06628        18       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582        0.48       0.491       0.434       0.131
# Saving model artifact on epoch  55
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     55/199     2.05G    0.0464   0.01962 6.166e-05   0.06608        17       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.537       0.479       0.449       0.136
# Saving model artifact on epoch  56
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     56/199     2.05G   0.04661   0.01946 6.689e-05   0.06613        19       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582        0.52       0.489       0.451       0.136
# Saving model artifact on epoch  57
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     57/199     2.05G   0.04649   0.01964 6.628e-05   0.06619        26       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.516       0.465       0.436       0.134
# Saving model artifact on epoch  58
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     58/199     2.05G   0.04622   0.01958 5.879e-05   0.06586        19       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.551        0.47        0.44       0.135
# Saving model artifact on epoch  59
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     59/199     2.05G   0.04598   0.01908 6.176e-05   0.06512        20       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.586       0.437       0.448       0.132
# Saving model artifact on epoch  60
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     60/199     2.05G   0.04623   0.01914  6.35e-05   0.06544        32       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.522       0.493       0.456       0.138
# Saving model artifact on epoch  61
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     61/199     2.05G   0.04626   0.01899 6.299e-05   0.06531        27       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.513        0.46        0.44       0.128
# Saving model artifact on epoch  62
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     62/199     2.05G   0.04584   0.01933 6.231e-05   0.06522        22       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.502         0.5       0.447       0.137
# Saving model artifact on epoch  63
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     63/199     2.05G   0.04587   0.01933 6.001e-05   0.06526        29       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.521       0.502       0.452       0.134
# Saving model artifact on epoch  64
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     64/199     2.05G   0.04559   0.01913 6.346e-05   0.06478        17       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.498       0.517       0.449       0.132
# Saving model artifact on epoch  65
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     65/199     2.05G   0.04536   0.01909 6.209e-05   0.06451        25       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.493       0.487       0.445       0.132
# Saving model artifact on epoch  66
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     66/199     2.05G   0.04555   0.01904 6.278e-05   0.06465        20       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.555       0.479       0.449       0.133
# Saving model artifact on epoch  67
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     67/199     2.05G     0.045   0.01924 5.756e-05   0.06429        22       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.539        0.47       0.442       0.129
# Saving model artifact on epoch  68
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     68/199     2.05G   0.04498   0.01917 6.115e-05   0.06421        19       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.519       0.491        0.44        0.13
# Saving model artifact on epoch  69
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     69/199     2.05G   0.04546   0.01928 6.492e-05    0.0648        21       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.494       0.496       0.449       0.136
# Saving model artifact on epoch  70
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     70/199     2.05G   0.04514   0.01898 5.764e-05   0.06418        28       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.549        0.48       0.451       0.133
# Saving model artifact on epoch  71
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     71/199     2.05G   0.04503   0.01889 5.601e-05   0.06397        27       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.517        0.47       0.427       0.129
# Saving model artifact on epoch  72
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     72/199     2.05G   0.04508   0.01907 5.777e-05   0.06422        25       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.506       0.467       0.432       0.131
# Saving model artifact on epoch  73
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     73/199     2.05G   0.04458   0.01913 5.697e-05   0.06376        36       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.496       0.485       0.432       0.134
# Saving model artifact on epoch  74
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     74/199     2.05G   0.04446   0.01905 5.682e-05   0.06357        24       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.543       0.453       0.427       0.128
# Saving model artifact on epoch  75
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     75/199     2.05G   0.04451   0.01892 5.696e-05   0.06348        21       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.493       0.491       0.428       0.126
# Saving model artifact on epoch  76
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     76/199     2.05G   0.04423   0.01878 5.863e-05   0.06306        29       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.531        0.46       0.424       0.127
# Saving model artifact on epoch  77
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     77/199     2.05G   0.04404   0.01914 5.612e-05   0.06324        28       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.498       0.483        0.43       0.128
# Saving model artifact on epoch  78
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     78/199     2.05G   0.04451    0.0189 5.499e-05   0.06346        29       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.507       0.487       0.443        0.13
# Saving model artifact on epoch  79
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     79/199     2.05G   0.04389   0.01885  5.89e-05    0.0628        18       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582        0.49       0.503       0.435        0.13
# Saving model artifact on epoch  80
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     80/199     2.05G   0.04392   0.01855 5.589e-05   0.06252        14       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.497       0.477       0.426       0.132
# Saving model artifact on epoch  81
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     81/199     2.05G    0.0439   0.01866 5.278e-05   0.06262        23       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582        0.49       0.496       0.438       0.134
# Saving model artifact on epoch  82
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     82/199     2.05G   0.04401   0.01873 5.203e-05   0.06279        21       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.485       0.479        0.41       0.124
# Saving model artifact on epoch  83
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     83/199     2.05G   0.04325   0.01845 5.198e-05   0.06175        24       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.515       0.463       0.417       0.124
# Saving model artifact on epoch  84
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     84/199     2.05G   0.04335   0.01847  5.31e-05   0.06187        22       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.491       0.464         0.4       0.121
# Saving model artifact on epoch  85
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     85/199     2.05G   0.04344   0.01847 5.518e-05   0.06196        18       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582        0.51       0.479       0.419       0.123
# Saving model artifact on epoch  86
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     86/199     2.05G   0.04326   0.01833   5.1e-05   0.06165        25       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.541       0.447       0.428        0.13
# Saving model artifact on epoch  87
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     87/199     2.05G   0.04344   0.01885 5.099e-05   0.06235        22       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.517       0.467       0.411       0.123
# Saving model artifact on epoch  88
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     88/199     2.05G   0.04293   0.01885 5.018e-05   0.06183        17       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.502       0.472       0.421       0.127
# Saving model artifact on epoch  89
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     89/199     2.05G   0.04292   0.01868 4.846e-05   0.06165        24       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.503       0.482       0.423       0.126
# Saving model artifact on epoch  90
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     90/199     2.05G   0.04266   0.01873 4.773e-05   0.06144        26       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.493       0.488       0.413       0.123
# Saving model artifact on epoch  91
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     91/199     2.05G   0.04264   0.01844  4.98e-05   0.06113        36       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.495       0.475       0.419       0.124
# Saving model artifact on epoch  92
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     92/199     2.05G   0.04245   0.01844 4.831e-05   0.06094        27       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582        0.47       0.496       0.414       0.129
# Saving model artifact on epoch  93
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     93/199     2.05G   0.04274   0.01802 5.174e-05   0.06082        16       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.497       0.472       0.415       0.122
# Saving model artifact on epoch  94
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     94/199     2.05G   0.04311   0.01817 7.347e-05   0.06136        24       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.508       0.467       0.423       0.127
# Saving model artifact on epoch  95
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     95/199     2.05G   0.04287   0.01849 4.743e-05   0.06141        23       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582        0.52       0.448       0.411       0.126
# Saving model artifact on epoch  96
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     96/199     2.05G   0.04212   0.01838 5.391e-05   0.06056        30       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.492       0.461       0.404       0.123
# Saving model artifact on epoch  97
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     97/199     2.05G   0.04197   0.01807 4.772e-05   0.06008        20       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582         0.5       0.475       0.401       0.118
# Saving model artifact on epoch  98
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     98/199     2.05G    0.0422   0.01819 5.132e-05   0.06044        24       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.512       0.462       0.401       0.116
# Saving model artifact on epoch  99
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     99/199     2.05G   0.04167   0.01809 4.805e-05    0.0598        18       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.472       0.479       0.399       0.118
# Saving model artifact on epoch  100
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    100/199     2.05G   0.04103   0.01797 4.547e-05   0.05904        26       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582        0.52       0.454       0.402        0.12
# Saving model artifact on epoch  101
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    101/199     2.05G   0.04151   0.01782 4.796e-05   0.05938        33       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.501        0.45       0.398       0.119
# Saving model artifact on epoch  102
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    102/199     2.05G   0.04096   0.01803 4.747e-05   0.05904        26       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.526       0.447       0.403        0.12
# Saving model artifact on epoch  103
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    103/199     2.05G    0.0413   0.01799 4.535e-05   0.05934        26       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.469       0.474       0.394       0.116
# Saving model artifact on epoch  104
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    104/199     2.05G   0.04087   0.01787 4.714e-05   0.05878        17       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.471        0.48       0.397       0.117
# Saving model artifact on epoch  105
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    105/199     2.05G   0.04067    0.0181 4.442e-05   0.05881        18       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.498       0.464       0.397       0.115
# Saving model artifact on epoch  106
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    106/199     2.05G   0.04081    0.0178 4.643e-05   0.05866        31       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.493       0.456       0.394       0.115
# Saving model artifact on epoch  107
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    107/199     2.05G   0.04069   0.01799 4.636e-05   0.05872        24       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.509       0.439       0.388       0.113
# Saving model artifact on epoch  108
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    108/199     2.05G   0.04048   0.01757 4.846e-05    0.0581        23       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.526       0.445       0.388       0.115
# Saving model artifact on epoch  109
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    109/199     2.05G   0.04018   0.01786 4.503e-05   0.05808        27       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.496       0.465       0.392       0.118
# Saving model artifact on epoch  110
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    110/199     2.05G   0.03985   0.01786 4.392e-05   0.05776        21       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582        0.51       0.477       0.402       0.117
# Saving model artifact on epoch  111
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    111/199     2.05G   0.03998   0.01783 4.608e-05   0.05785        17       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.502       0.456       0.387       0.112
# Saving model artifact on epoch  112
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    112/199     2.05G   0.03996   0.01739 4.647e-05    0.0574        25       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.498       0.441       0.377       0.111
# Saving model artifact on epoch  113
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
# ...
#    158/199     2.05G   0.03339   0.01544 3.143e-05   0.04886        25       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.498        0.42       0.348       0.101
# Saving model artifact on epoch  159
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    159/199     2.05G   0.03283    0.0153 3.127e-05   0.04817        29       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.458       0.457        0.35       0.101
# Saving model artifact on epoch  160
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    160/199     2.05G   0.03306   0.01515 3.084e-05   0.04825        29       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.444       0.464       0.346      0.0993
# Saving model artifact on epoch  161
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    161/199     2.05G   0.03284    0.0152 3.199e-05   0.04807        27       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.454       0.454       0.344      0.0995
# Saving model artifact on epoch  162
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    162/199     2.05G   0.03276   0.01519 3.133e-05   0.04798        21       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.481       0.423        0.34      0.0982
# Saving model artifact on epoch  163
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    163/199     2.05G   0.03243   0.01481 2.947e-05   0.04726        31       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.463        0.44       0.339      0.0978
# Saving model artifact on epoch  164
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    164/199     2.05G   0.03254   0.01499 2.947e-05   0.04756        20       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.463       0.438       0.339      0.0984
# Saving model artifact on epoch  165
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    165/199     2.05G   0.03237   0.01455 3.073e-05   0.04695        25       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.454       0.455        0.34      0.0981
# Saving model artifact on epoch  166
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    166/199     2.05G   0.03217   0.01488 2.901e-05   0.04708        17       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582        0.47       0.441        0.34      0.0985
# Saving model artifact on epoch  167
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    167/199     2.05G   0.03234   0.01467  2.88e-05   0.04704        17       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.473       0.441       0.343      0.0994
# Saving model artifact on epoch  168
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    168/199     2.05G   0.03191   0.01458 2.897e-05   0.04652        31       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582        0.47       0.445       0.341      0.0993
# Saving model artifact on epoch  169
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    169/199     2.05G   0.03215   0.01453 3.008e-05   0.04671        18       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.487       0.434       0.343      0.0999
# Saving model artifact on epoch  170
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    170/199     2.05G   0.03179   0.01461  2.94e-05   0.04643        22       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.493       0.425        0.34      0.0996
# Saving model artifact on epoch  171
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    171/199     2.05G   0.03125   0.01439 2.775e-05   0.04567        17       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.469       0.441       0.339       0.099
# Saving model artifact on epoch  172
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    172/199     2.05G   0.03135   0.01448 2.714e-05   0.04586        22       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.483        0.43       0.339      0.0995
# Saving model artifact on epoch  173
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    173/199     2.05G   0.03117   0.01441 2.721e-05   0.04561        26       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.489       0.427        0.34      0.0998
# Saving model artifact on epoch  174
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    174/199     2.05G   0.03121   0.01399  2.73e-05   0.04523        24       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.475       0.434        0.34      0.0997
# Saving model artifact on epoch  175
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    175/199     2.05G   0.03122   0.01431 2.789e-05   0.04555        24       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.456       0.454       0.341      0.0992
# Saving model artifact on epoch  176
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    176/199     2.05G   0.03098   0.01406 2.694e-05   0.04507        19       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.451        0.46        0.34      0.0989
# Saving model artifact on epoch  177
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    177/199     2.05G   0.03089   0.01427 2.632e-05   0.04519        18       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.453       0.461       0.338      0.0981
# Saving model artifact on epoch  178
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    178/199     2.05G   0.03084   0.01418 2.735e-05   0.04505        25       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.458       0.453        0.34      0.0984
# Saving model artifact on epoch  179
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    179/199     2.05G   0.03086   0.01439 2.697e-05   0.04528        25       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.453       0.454       0.337      0.0978
# Saving model artifact on epoch  180
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    180/199     2.05G   0.03059   0.01415  2.68e-05   0.04477        28       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.486       0.424       0.335      0.0972
# Saving model artifact on epoch  181
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    181/199     2.05G   0.03062   0.01416 2.598e-05   0.04481        20       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.477       0.435       0.337      0.0971
# Saving model artifact on epoch  182
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    182/199     2.05G    0.0305   0.01389 2.774e-05   0.04442        33       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.486       0.429       0.337      0.0965
# Saving model artifact on epoch  183
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    183/199     2.05G   0.03002    0.0141 2.649e-05   0.04414        22       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.481       0.436       0.335      0.0962
# Saving model artifact on epoch  184
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    184/199     2.05G   0.03031   0.01399 2.595e-05   0.04433        23       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.482       0.433       0.336      0.0959
# Saving model artifact on epoch  185
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    185/199     2.05G   0.03026   0.01396 2.669e-05   0.04425        25       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582        0.48        0.43       0.334      0.0957
# Saving model artifact on epoch  186
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    186/199     2.05G   0.03019   0.01392  2.65e-05   0.04414        21       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.485       0.431       0.336      0.0955
# Saving model artifact on epoch  187
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    187/199     2.05G   0.03003   0.01376 2.626e-05   0.04381        20       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582        0.48       0.433       0.333      0.0951
# Saving model artifact on epoch  188
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    188/199     2.05G    0.0301   0.01403 2.621e-05   0.04415        30       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.482       0.432       0.334      0.0953
# Saving model artifact on epoch  189
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    189/199     2.05G   0.02997   0.01376 2.503e-05   0.04376        20       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.492       0.418       0.331      0.0954
# Saving model artifact on epoch  190
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    190/199     2.05G   0.02982   0.01371 2.598e-05   0.04355        17       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.488       0.425       0.333      0.0954
# Saving model artifact on epoch  191
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    191/199     2.05G   0.02958   0.01369 2.563e-05   0.04329        26       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.489       0.422       0.332      0.0951
# Saving model artifact on epoch  192
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    192/199     2.05G   0.02958   0.01368 2.516e-05   0.04329        27       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.489        0.42       0.331      0.0949
# Saving model artifact on epoch  193
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    193/199     2.05G   0.02947   0.01362 2.434e-05   0.04311        20       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.492       0.421       0.332      0.0946
# Saving model artifact on epoch  194
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    194/199     2.05G    0.0295   0.01376 2.395e-05   0.04328        20       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.493        0.42       0.332      0.0941
# Saving model artifact on epoch  195
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    195/199     2.05G   0.02932   0.01364 2.509e-05   0.04299        21       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.499       0.416       0.331       0.094
# Saving model artifact on epoch  196
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    196/199     2.05G    0.0292   0.01349 2.429e-05   0.04272        34       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.491       0.417       0.328      0.0938
# Saving model artifact on epoch  197
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    197/199     2.05G   0.02949   0.01357 2.471e-05   0.04309        23       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.484        0.42       0.328      0.0938
# Saving model artifact on epoch  198
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    198/199     2.05G   0.02923   0.01368 2.528e-05   0.04293        27       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.474       0.421       0.325      0.0937
# Saving model artifact on epoch  199
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    199/199     2.05G   0.02934   0.01357  2.47e-05   0.04293        30       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all        1267        1582       0.442       0.453       0.325      0.0934
#              opacity        1267        1582       0.442       0.453       0.325      0.0934
# 200 epochs completed in 2.012 hours.
#
# Optimizer stripped from kaggle-siim-covid/exp3/weights/last.pt, 14.4MB
# Optimizer stripped from kaggle-siim-covid/exp3/weights/best.pt, 14.4MB
# Images sizes do not match. This will causes images to be display incorrectly in the UI.
#
# wandb: Waiting for W&B process to finish, PID 1070721
# wandb: Program ended successfully.

# %% [markdown]
# ## Model Saved Automatically as Artifact
#
# Since it's a kernel based competition, you can easily download the best model from the W&B Artifacts UI and upload as a Kaggle dataset that you can load in your inference kernel (internel disabled).
#
# ### [Path to saved model $\rightarrow$](https://wandb.ai/ayush-thakur/kaggle-siim-covid/artifacts/model/run_jbt74n7q_model/4c3ca5752dba99bd227e)
#
# ![img](https://i.imgur.com/KhRLQvR.png)
#
# > 📍 Download the model with the `best` alias tagged to it.

# %% [markdown]
# # Inference
#
# You will probably use a `Submission.ipynb` kernel to run all the predictions. After training a YOLOv5 based object detector -> head to the artifacts page and download the best model -> upload the model as a Kaggle dataset -> Use it with the submission folder.
#
# > 📍 Note that you might have to clone the YOLOv5 repository in a Kaggle dataset as well.
#
# In this section, I will show you how you can do the inference and modify the predicted bounding box coordinates.

# %%
# !ls

# %%
# TEST_PATH = '/kaggle/input/siim-covid19-resized-to-256px-jpg/test/' # absolute path
TEST_PATH = '../input/test/' # absolute path

# %% [markdown]
# Since I am training the model in this kernel itself, I will not be using the method that I have described above. The best model is saved in the directory `project_name/exp*/weights/best.pt`. In `exp*`, * can be 1, 2, etc.

# %%
# MODEL_PATH = 'kaggle-siim-covid/exp/weights/best.pt'
MODEL_PATH = '../models/exp1/best.pt'

# %% [markdown]
# ```
# --weights {MODEL_PATH} \ # path to the best model.
# --source {TEST_PATH} \ # absolute path to the test images.
# --img {IMG_SIZE} \ # Size of image
# --conf 0.281 \ # Confidence threshold (default is 0.25)
# --iou-thres 0.5 \ # IOU threshold (default is 0.45)
# --max-det 3 \ # Number of detections per image (default is 1000)
# --save-txt \ # Save predicted bounding box coordinates as txt files
# --save-conf # Save the confidence of prediction for each bounding box
# ```

# %%
# !python detect.py --weights {MODEL_PATH} \
                  --source {TEST_PATH} \
                  --img {IMG_SIZE} \
                  --conf 0.281 \
                  --iou-thres 0.5 \
                  --max-det 3 \
                  --save-txt \
                  --save-conf

# %% [markdown]
# ### How to find the confidence score?
#
# 1. First first the [W&B run page](https://wandb.ai/ayush-thakur/kaggle-siim-covid/runs/jbt74n7q) generated by training the YOLOv5 model.
#
# 2. Go to the media panel -> click on the F1_curve.png file to get a rough estimate of the threshold -> go to the Bounding Box Debugger panel and interactively adjust the confidence threshold.
#
# ![img](https://i.imgur.com/cCUnTBw.gif)

# %% [markdown]
# > 📍 The bounding box coordinates are saved as text file per image name. It is saved in this directory `runs/detect/exp3/labels`.

# %%
PRED_PATH = 'runs/detect/exp3/labels'
# !ls {PRED_PATH}

# %%
# Visualize predicted coordinates.
# %cat runs/detect/exp3/labels/ba91d37ee459.txt

# %% [markdown]
# > 📍 Note: 1 is class id (opacity), the first four float numbers are `x_center`, `y_center`, `width` and `height`. The final float value is `confidence`.

# %%
prediction_files = os.listdir(PRED_PATH)
print('Number of test images predicted as opaque: ', len(prediction_files))

# %% [markdown]
# > 📍 Out of 1263 test images, 583 were predicted with `opacity` label and thus we have that many prediction txt files.

# %% [markdown]
# # Submission
#
# In this section, I will show how you can use YOLOv5 as object detector and prepare `submission.csv` file.

# %%
# The submisison requires xmin, ymin, xmax, ymax format. 
# YOLOv5 returns x_center, y_center, width, height
def correct_bbox_format(bboxes):
    correct_bboxes = []
    for b in bboxes:
        xc, yc = int(np.round(b[0]*IMG_SIZE)), int(np.round(b[1]*IMG_SIZE))
        w, h = int(np.round(b[2]*IMG_SIZE)), int(np.round(b[3]*IMG_SIZE))

        xmin = xc - int(np.round(w/2))
        xmax = xc + int(np.round(w/2))
        ymin = yc - int(np.round(h/2))
        ymax = yc + int(np.round(h/2))
        
        correct_bboxes.append([xmin, xmax, ymin, ymax])
        
    return correct_bboxes

# Read the txt file generated by YOLOv5 during inference and extract 
# confidence and bounding box coordinates.
def get_conf_bboxes(file_path):
    confidence = []
    bboxes = []
    with open(file_path, 'r') as file:
        for line in file:
            preds = line.strip('\n').split(' ')
            preds = list(map(float, preds))
            confidence.append(preds[-1])
            bboxes.append(preds[1:-1])
    return confidence, bboxes

# %%
# Read the submisison file
# sub_df = pd.read_csv('/kaggle/input/siim-covid19-detection/sample_submission.csv')
sub_df = pd.read_csv('../input/sample_submission.csv')
sub_df.tail()

# %%
# Prediction loop for submission
predictions = []

for i in tqdm(range(len(sub_df))):
    row = sub_df.loc[i]
    id_name = row.id.split('_')[0]
    id_level = row.id.split('_')[-1]
    
    if id_level == 'study':
        # do study-level classification
        predictions.append("Negative 1 0 0 1 1") # dummy prediction
        
    elif id_level == 'image':
        # we can do image-level classification here.
        # also we can rely on the object detector's classification head.
        # for this example submisison we will use YOLO's classification head. 
        # since we already ran the inference we know which test images belong to opacity.
        if f'{id_name}.txt' in prediction_files:
            # opacity label
            confidence, bboxes = get_conf_bboxes(f'{PRED_PATH}/{id_name}.txt')
            bboxes = correct_bbox_format(bboxes)
            pred_string = ''
            for j, conf in enumerate(confidence):
                pred_string += f'opacity {conf} ' + ' '.join(map(str, bboxes[j])) + ' '
            predictions.append(pred_string[:-1]) 
        else:
            predictions.append("None 1 0 0 1 1")

# %%
sub_df['PredictionString'] = predictions
sub_df.to_csv('submission.csv', index=False)
sub_df.tail()

# %% [markdown]
# # WORK IN PROGRESS
#
# Final component is model prediction visualization which is an optional debugging tool I would like to share. :)
#
# Consider upvoting if you find the work useful.
